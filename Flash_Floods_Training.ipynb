# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import learning_curve
from sklearn.pipeline import make_pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import FunctionTransformer
from pandas.plotting import scatter_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import matplotlib.pyplot as plt

# %%
# Load the dataset
file_path = "dataset_source.csv"
df = pd.read_csv(file_path)

# Display basic information and the first few rows
df_info = df.info()
df_head = df.head()


df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   injuries_direct   761 non-null    int64
#  1   deaths_direct     761 non-null    int64
#  2   event_latitude    761 non-null    float64
#  3   event_longitude   761 non-null    float64
#  4   event_range       761 non-null    float64
#  5   event_type        761 non-null    object
#  6   event_begin_time  761 non-null    object
#  7   event_end_time    761 non-null    object
#  8   damage_property   761 non-null    int64
#  9   source            761 non-null    object
#  10  rn                761 non-null    int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 65.5+ KB
#         injuries_direct  deaths_direct  event_latitude  event_longitude  \
# count        761.000000     761.000000      761.000000       761.000000
# unique              NaN            NaN             NaN              NaN
# top                 NaN            NaN             NaN              NaN
# freq                NaN            NaN             NaN              NaN
# mean           2.721419       0.629435       35.747277       -89.650005
# std            6.361370       1.299545        6.099935        17.587892
# min            0.000000       0.000000        7.360600      -124.120000
# 25%            0.000000       0.000000       33.000000       -97.096600
# 50%            1.000000       0.000000       36.180000       -89.150000
# 75%            2.000000       1.000000       39.087400       -81.810000
# max           88.000000       9.000000       48.270000       151.858900
#
#         event_range   event_type     event_begin_time       event_end_time  \
# count    761.000000          761                  761                  761
# unique          NaN            4                  449                  449
# top             NaN  flash flood  2024-07-10T21:30:00  2023-01-01T23:59:00
# freq            NaN          200                   10                   13
# mean       2.655440          NaN                  NaN                  NaN
# std        3.083233          NaN                  NaN                  NaN
# min        0.000000          NaN                  NaN                  NaN
# 25%        0.910000          NaN                  NaN                  NaN
# 50%        1.820000          NaN                  NaN                  NaN
# 75%        3.150000          NaN                  NaN                  NaN
# max       25.960000          NaN                  NaN                  NaN
#
#         damage_property            source          rn
# count      7.610000e+02               761  761.000000
# unique              NaN                30         NaN
# top                 NaN  NWS Storm Survey         NaN
# freq                NaN               223         NaN
# mean       1.545455e+07               NaN   96.374507
# std        1.071591e+08               NaN   56.148045
# min        0.000000e+00               NaN    1.000000
# 25%        0.000000e+00               NaN   48.000000
# 50%        1.500000e+04               NaN   96.000000
# 75%        8.500000e+05               NaN  143.000000
# max        1.800000e+09               NaN  200.000000

# %%
# Load the dataset
file_path = "dataset_source.csv"
df = pd.read_csv(file_path)

# Display basic information and the first few rows
df_info = df.info()
df_head = df.head()


df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   injuries_direct   761 non-null    int64
#  1   deaths_direct     761 non-null    int64
#  2   event_latitude    761 non-null    float64
#  3   event_longitude   761 non-null    float64
#  4   event_range       761 non-null    float64
#  5   event_type        761 non-null    object
#  6   event_begin_time  761 non-null    object
#  7   event_end_time    761 non-null    object
#  8   damage_property   761 non-null    int64
#  9   source            761 non-null    object
#  10  rn                761 non-null    int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 65.5+ KB
#         injuries_direct  deaths_direct  event_latitude  event_longitude  \
# count        761.000000     761.000000      761.000000       761.000000
# unique              NaN            NaN             NaN              NaN
# top                 NaN            NaN             NaN              NaN
# freq                NaN            NaN             NaN              NaN
# mean           2.721419       0.629435       35.747277       -89.650005
# std            6.361370       1.299545        6.099935        17.587892
# min            0.000000       0.000000        7.360600      -124.120000
# 25%            0.000000       0.000000       33.000000       -97.096600
# 50%            1.000000       0.000000       36.180000       -89.150000
# 75%            2.000000       1.000000       39.087400       -81.810000
# max           88.000000       9.000000       48.270000       151.858900
#
#         event_range   event_type     event_begin_time       event_end_time  \
# count    761.000000          761                  761                  761
# unique          NaN            4                  449                  449
# top             NaN  flash flood  2024-07-10T21:30:00  2023-01-01T23:59:00
# freq            NaN          200                   10                   13
# mean       2.655440          NaN                  NaN                  NaN
# std        3.083233          NaN                  NaN                  NaN
# min        0.000000          NaN                  NaN                  NaN
# 25%        0.910000          NaN                  NaN                  NaN
# 50%        1.820000          NaN                  NaN                  NaN
# 75%        3.150000          NaN                  NaN                  NaN
# max       25.960000          NaN                  NaN                  NaN
#
#         damage_property            source          rn
# count      7.610000e+02               761  761.000000
# unique              NaN                30         NaN
# top                 NaN  NWS Storm Survey         NaN
# freq                NaN               223         NaN
# mean       1.545455e+07               NaN   96.374507
# std        1.071591e+08               NaN   56.148045
# min        0.000000e+00               NaN    1.000000
# 25%        0.000000e+00               NaN   48.000000
# 50%        1.500000e+04               NaN   96.000000
# 75%        8.500000e+05               NaN  143.000000
# max        1.800000e+09               NaN  200.000000

# %%
# Convert time columns to datetime
df['event_begin_time'] = pd.to_datetime(df['event_begin_time'])
df['event_end_time'] = pd.to_datetime(df['event_end_time'])

# Calculate event_duration in minutes
df['event_duration'] = (df['event_end_time'] - df['event_begin_time']).dt.total_seconds() / 60

# Convert event_range to float (if not already)
df['event_range'] = df['event_range'].astype(float)

# Drop the 'rn' column
df.drop(columns=['rn'], inplace=True)

# One-hot encode 'event_type'
df = pd.get_dummies(df, columns=['event_type'], prefix='event')
df = pd.get_dummies(df, columns=['source'], prefix='source')

# %%
df.head()
# Out:
#    injuries_direct  deaths_direct  event_latitude  event_longitude  \
# 0                5              0         35.2174        -111.7912
# 1                5              0         35.1951        -111.7083
# 2                2              0         43.2988        -111.1497
# 3                4              0         43.3091        -111.1637
# 4                3              0         43.9100        -116.8100
#
#    event_range    event_begin_time      event_end_time  damage_property  \
# 0         2.36 2024-10-18 07:00:00 2024-10-18 07:10:00                0
# 1         3.31 2024-10-18 07:00:00 2024-10-18 07:10:00                0
# 2         5.00 2024-08-10 12:36:00 2024-08-10 12:50:00                0
# 3         4.00 2024-08-10 12:35:00 2024-08-10 12:45:00                0
# 4         4.18 2024-06-26 13:00:00 2024-06-26 13:10:00                0
#
#    event_duration  event_flash flood  ...  source_NWS Storm Survey  \
# 0            10.0              False  ...                    False
# 1            10.0              False  ...                    False
# 2            14.0              False  ...                    False
# 3            10.0              False  ...                    False
# 4            10.0              False  ...                    False
#
#    source_Newspaper  source_OFFICIAL NWS OBS.  source_Other Federal Agency  \
# 0             False                     False                        False
# 1             False                     False                        False
# 2             False                     False                        False
# 3             False                     False                        False
# 4             False                     False                        False
#
#    source_Park/Forest Service  source_Public  source_Social Media  \
# 0                       False          False                False
# 1                       False          False                False
# 2                       False           True                False
# 3                       False           True                False
# 4                       False          False                False
#
#    source_State Official  source_TRAINED SPOTTER  source_Trained Spotter
# 0                  False                   False                   False
# 1                  False                   False                   False
# 2                  False                   False                   False
# 3                  False                   False                   False
# 4                  False                   False                   False
#
# [5 rows x 43 columns]

# %%
df.columns.tolist()
# Out:
# ['injuries_direct',
#  'deaths_direct',
#  'event_latitude',
#  'event_longitude',
#  'event_range',
#  'event_begin_time',
#  'event_end_time',
#  'damage_property',
#  'event_duration',
#  'event_flash flood',
#  'event_hail',
#  'event_thunderstorm wind',
#  'event_tornado',
#  'source_911 Call Center',
#  'source_AMATEUR RADIO',
#  'source_ASOS',
#  'source_Amateur Radio',
#  'source_Broadcast Media',
#  'source_COOP Observer',
#  'source_CoCoRaHS',
#  'source_County Official',
#  'source_Department of Highways',
#  'source_EMERGENCY MANAGER',
#  'source_Emergency Manager',
#  'source_FIRE DEPT/RESCUE SQUAD',
#  'source_Fire Department/Rescue',
#  'source_GENERAL PUBLIC',
#  'source_LAW ENFORCEMENT',
#  'source_Law Enforcement',
#  'source_Local Official',
#  'source_NEWSPAPER',
#  'source_NWS Employee',
#  'source_NWS STORM SURVEY',
#  'source_NWS Storm Survey',
#  'source_Newspaper',
#  'source_OFFICIAL NWS OBS.',
#  'source_Other Federal Agency',
#  'source_Park/Forest Service',
#  'source_Public',
#  'source_Social Media',
#  'source_State Official',
#  'source_TRAINED SPOTTER',
#  'source_Trained Spotter']

# %% [markdown]
# # Data Visualization

# %%
# Filter for flash flood events
df_flashflood = df[df['event_flash flood'] == 1].copy()

source_cols = [col for col in df_flashflood.columns if col.startswith('source_')]

# Drop source columns that are all zeros for that row (i.e., retain only true sources)
df_flashflood_filtered = df_flashflood[df_flashflood[source_cols].sum(axis=1) > 0].copy()

# Now drop all event and irrelevant columns
X_flood = df_flashflood_filtered.drop(columns=[
    'damage_property',
    'event_begin_time',
    'event_end_time',
    'event_tornado',
    'event_hail',
    'event_flash flood',
    'event_thunderstorm wind'
] + [col for col in source_cols if df_flashflood_filtered[col].nunique() == 1 and df_flashflood_filtered[col].iloc[0] == 0])

df_flashflood['damage_property_log'] = np.log1p(df_flashflood['damage_property'])
y_flood = df_flashflood['damage_property_log']
# Prepare features and target
# X_flood = df_flashflood.drop(columns=['damage_property','event_begin_time', 'event_end_time', 'event_tornado', 'event_hail', 'event_flash flood', 'event_thunderstorm wind'])
#y_flood = df_flashflood['damage_property']
# y_flood = np.log1p(df_flashflood['damage_property'])  # to reduce scale issues

# Split and scale
X_train_flood, X_test_flood, y_train_flood, y_test_flood = train_test_split(X_flood, y_flood, test_size=0.2, random_state=42)
scaler = StandardScaler()
X_train_scaled_flood = pd.DataFrame(scaler.fit_transform(X_train_flood), columns=X_flood.columns, index=X_train_flood.index)
X_test_scaled_flood = pd.DataFrame(scaler.transform(X_test_flood), columns=X_flood.columns, index=X_test_flood.index)

# %% [markdown]
# Since, damage cost column contains values from 0 to 500000000. We convert the outcome into a log value and predict the log value

# %%
np.max(df_flashflood['damage_property'])
# Out:
# 500000000

# %%
plt.figure(figsize=(8, 4))
plt.hist(df_flashflood['damage_property_log'], bins=200, edgecolor='k')
plt.xlabel('y value')
plt.ylabel('Frequency')
plt.title('Histogram of raw Damage Cost')
plt.tight_layout()
plt.show()

# %%
# Compute correlation matrix
corr_matrix = X_train_scaled_flood.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Heatmap of Scaled Flash Flood Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Linear Regression and Random Forest Regressor

# %%
# Initialize and train tornado models
tornado_models = {
    "Linear Regression (Flash Floods)": LinearRegression(),
    "Random Forest Regressor (Flash Floods)": RandomForestRegressor(n_estimators=100, random_state=42)
}

# Train, predict, and evaluate
results_tornado = []
for name, model in tornado_models.items():
    model.fit(X_train_scaled_flood, y_train_flood)
    preds = model.predict(X_test_scaled_flood)
    rmse_tornado = np.sqrt(mean_squared_error(y_test_flood, preds))
    r2_tornado = r2_score(y_test_flood, preds)
    results_tornado.append({
        "Model": name,
        "RMSE": rmse_tornado,
        "R² Score": r2_tornado
    })

# Show results
results_tornado_df = pd.DataFrame(results_tornado)
print(results_tornado_df)
# Out:
#                                     Model      RMSE  R² Score
# 0        Linear Regression (Flash Floods)  5.153195  0.343202
# 1  Random Forest Regressor (Flash Floods)  0.799937  0.984173

# %%
# Plot learning curves using MSE for tornado models
for name, model in tornado_models.items():
    train_sizes, train_scores, test_scores = learning_curve(
        estimator=model,
        X=X_train_scaled_flood,  # Tornado features
        y=y_train_flood,         # Tornado target
        train_sizes=np.linspace(0.1, 1.0, 10),
        cv=5,
        scoring='neg_mean_squared_error',
        n_jobs=-1
    )

    # Convert negative MSE to positive values
    train_mse_mean = -np.mean(train_scores, axis=1)
    test_mse_mean = -np.mean(test_scores, axis=1)

    # Plot
    plt.figure(figsize=(8, 6))
    plt.plot(train_sizes, train_mse_mean, label="Training MSE", marker='o')
    plt.plot(train_sizes, test_mse_mean, label="Validation MSE", marker='s')
    plt.title(f"Learning Curve: {name}")
    plt.xlabel("Training Set Size")
    plt.ylabel("Mean Squared Error")
    plt.legend(loc="best")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
tornado_models = {
    "Linear Regression (Flash Floods)": LinearRegression(),
    "Random Forest Regressor (Flash Floods)": RandomForestRegressor(
        n_estimators=100, random_state=42
    ),
}

pred_dict = {}          # store predictions for later plotting
results_tornado = []    # store metrics for a quick table

for name, model in tornado_models.items():
    model.fit(X_train_scaled_flood, y_train_flood)
    preds = model.predict(X_test_scaled_flood)

    # Save for plotting
    pred_dict[name] = preds

    # Metrics
    rmse = np.sqrt(mean_squared_error(y_test_flood, preds))
    r2   = r2_score(y_test_flood, preds)

    results_tornado.append({"Model": name, "RMSE": rmse, "R² Score": r2})

# Neat metrics table in case you need it
results_tornado_df = pd.DataFrame(results_tornado)
print(results_tornado_df.to_string(index=False))


plt.figure(figsize=(10, 5))

# Ground‑truth
plt.plot(
    y_test_flood.values,
    label="True value",
    linewidth=2,
)

# Each model’s curve
for name, preds in pred_dict.items():
    plt.plot(
        preds,
        linewidth=1,
        alpha=0.8,
        label=name,        # legend entry
    )

plt.ylim(-10, 30)                 # keep your original y‑axis limits
plt.xlabel("Sample index")
plt.ylabel("Damage cost")
plt.title("True vs. Predicted values on test set")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#                                  Model     RMSE  R² Score
#       Linear Regression (Flash Floods) 5.153195  0.343202
# Random Forest Regressor (Flash Floods) 0.799937  0.984173

# %%
# SAve the model
rf_model = tornado_models["Random Forest Regressor (Flash Floods)"]

joblib.dump(rf_model, "models/random_forest_tornado_flash_flood.pkl")   # any filename you like
# Out:
# ['models/random_forest_tornado_flash_flood.pkl']

# %% [markdown]
# # Neural Network Regression

# %%
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_train_t = torch.tensor(X_train_scaled_flood.values, dtype=torch.float32)
X_test_t  = torch.tensor(X_test_scaled_flood.values,  dtype=torch.float32)

# scale the target (z‑score)
#y_scaler     = StandardScaler()
##y_train_z    = y_scaler.fit_transform(y_train.reshape(-1, 1)).ravel()
#y_test_z     = y_scaler.transform(y_test.reshape(-1, 1)).ravel()

y_train_t = torch.tensor(y_train_flood.values, dtype=torch.float32).unsqueeze(1)
y_test_t  = torch.tensor(y_test_flood.values, dtype=torch.float32).unsqueeze(1)

ds_full = TensorDataset(X_train_t, y_train_t)

# Validation split  (80 % train / 20 % val)
val_frac = 0.2
val_size = int(len(ds_full) * val_frac)
train_size = len(ds_full) - val_size
ds_train, ds_val = random_split(ds_full, [train_size, val_size],
                                generator=torch.Generator().manual_seed(42))

loader_train = DataLoader(ds_train, batch_size=16, shuffle=True)
loader_val   = DataLoader(ds_val,   batch_size=64, shuffle=False)

# %%
class MLPRegressor(nn.Module):
    def __init__(self, in_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)        # linear output (z‑score of y)
        )

    def forward(self, x):
        return self.net(x)

model = MLPRegressor(X_train_t.shape[1]).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)


best_val = np.inf
patience, patience_cnt = 20, 0
n_epochs = 500
step = 0
training_loss = []
val_loss_list = []
for epoch in range(1, n_epochs + 1):
    # --- training step ---
    model.train()
    for xb, yb in loader_train:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        step +=1
        print(f"Epoch: {epoch}, Training Loss step:{step}-MSE:{loss}")
        training_loss.append(loss)

    # --- validation ---
    model.eval()
    with torch.no_grad():
        val_losses = []
        for xb, yb in loader_val:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            val_losses.append(criterion(pred, yb).item())
        val_loss = np.mean(val_losses)
        val_loss_list.append(val_loss)
        

    # early‑stopping logic
    # if val_loss < best_val - 0.0001:
    #     best_val = val_loss
    #     best_state = model.state_dict()
    #     patience_cnt = 0
    # else:
    #     patience_cnt += 1
    #     if patience_cnt >= patience:
    #         print(f"Early stopping at epoch {epoch}")
    #         break
# Out:
# Epoch: 1, Training Loss step:1-MSE:80.24976348876953
# Epoch: 1, Training Loss step:2-MSE:137.0023651123047
# Epoch: 1, Training Loss step:3-MSE:108.89219665527344
# Epoch: 1, Training Loss step:4-MSE:148.62014770507812
# Epoch: 1, Training Loss step:5-MSE:73.1795883178711
# Epoch: 1, Training Loss step:6-MSE:102.69561004638672
# Epoch: 1, Training Loss step:7-MSE:116.21893310546875
# Epoch: 1, Training Loss step:8-MSE:129.49432373046875
# Epoch: 2, Training Loss step:9-MSE:158.4828338623047
# Epoch: 2, Training Loss step:10-MSE:109.69969940185547
# Epoch: 2, Training Loss step:11-MSE:76.57643127441406
# Epoch: 2, Training Loss step:12-MSE:87.64921569824219
# Epoch: 2, Training Loss step:13-MSE:99.30726623535156
# Epoch: 2, Training Loss step:14-MSE:130.44715881347656
# Epoch: 2, Training Loss step:15-MSE:90.20132446289062
# Epoch: 2, Training Loss step:16-MSE:107.49028015136719
# Epoch: 3, Training Loss step:17-MSE:94.96737670898438
# Epoch: 3, Training Loss step:18-MSE:100.35557556152344
# Epoch: 3, Training Loss step:19-MSE:70.94629669189453
# Epoch: 3, Training Loss step:20-MSE:93.6617202758789
# Epoch: 3, Training Loss step:21-MSE:87.72004699707031
# Epoch: 3, Training Loss step:22-MSE:137.51596069335938
# Epoch: 3, Training Loss step:23-MSE:132.1744842529297
# Epoch: 3, Training Loss step:24-MSE:74.02960968017578
# Epoch: 4, Training Loss step:25-MSE:93.71260070800781
# Epoch: 4, Training Loss step:26-MSE:60.037689208984375
# Epoch: 4, Training Loss step:27-MSE:81.97846984863281
# Epoch: 4, Training Loss step:28-MSE:115.22582244873047
# Epoch: 4, Training Loss step:29-MSE:88.50045013427734
# Epoch: 4, Training Loss step:30-MSE:81.82061767578125
# Epoch: 4, Training Loss step:31-MSE:82.48051452636719
# Epoch: 4, Training Loss step:32-MSE:68.36225891113281
# Epoch: 5, Training Loss step:33-MSE:63.05519104003906
# Epoch: 5, Training Loss step:34-MSE:67.2575454711914
# Epoch: 5, Training Loss step:35-MSE:38.25157928466797
# Epoch: 5, Training Loss step:36-MSE:92.68157196044922
# Epoch: 5, Training Loss step:37-MSE:48.424903869628906
# Epoch: 5, Training Loss step:38-MSE:70.50341796875
# Epoch: 5, Training Loss step:39-MSE:61.16957092285156
# Epoch: 5, Training Loss step:40-MSE:65.54700469970703
# Epoch: 6, Training Loss step:41-MSE:49.056785583496094
# Epoch: 25, Training Loss step:193-MSE:8.167530059814453
# Epoch: 25, Training Loss step:194-MSE:7.830985069274902
# Epoch: 25, Training Loss step:195-MSE:16.68758773803711
# Epoch: 25, Training Loss step:196-MSE:12.851303100585938
# Epoch: 25, Training Loss step:197-MSE:17.18784523010254
# Epoch: 25, Training Loss step:198-MSE:11.087121963500977
# Epoch: 25, Training Loss step:199-MSE:8.57344913482666
# Epoch: 25, Training Loss step:200-MSE:9.519247055053711
# Epoch: 26, Training Loss step:201-MSE:6.472527980804443
# Epoch: 26, Training Loss step:202-MSE:10.680868148803711
# Epoch: 26, Training Loss step:203-MSE:12.776103973388672
# Epoch: 26, Training Loss step:204-MSE:8.12110424041748
# Epoch: 26, Training Loss step:205-MSE:12.725910186767578
# Epoch: 26, Training Loss step:206-MSE:11.035886764526367
# Epoch: 26, Training Loss step:207-MSE:24.532047271728516
# Epoch: 26, Training Loss step:208-MSE:5.768862247467041
# Epoch: 27, Training Loss step:209-MSE:11.850004196166992
# Epoch: 27, Training Loss step:210-MSE:14.141244888305664
# Epoch: 27, Training Loss step:211-MSE:3.7981491088867188
# Epoch: 27, Training Loss step:212-MSE:10.636512756347656
# Epoch: 27, Training Loss step:213-MSE:4.703469276428223
# Epoch: 27, Training Loss step:214-MSE:12.865934371948242
# Epoch: 27, Training Loss step:215-MSE:17.053401947021484
# Epoch: 27, Training Loss step:216-MSE:7.441875457763672
# Epoch: 28, Training Loss step:217-MSE:11.369955062866211
# Epoch: 28, Training Loss step:218-MSE:9.012189865112305
# Epoch: 28, Training Loss step:219-MSE:6.9530792236328125
# Epoch: 28, Training Loss step:220-MSE:11.508760452270508
# Epoch: 28, Training Loss step:221-MSE:16.751068115234375
# Epoch: 28, Training Loss step:222-MSE:9.845481872558594
# Epoch: 28, Training Loss step:223-MSE:9.168956756591797
# Epoch: 28, Training Loss step:224-MSE:9.316307067871094
# Epoch: 29, Training Loss step:225-MSE:7.1420087814331055
# Epoch: 29, Training Loss step:226-MSE:10.22064208984375
# Epoch: 29, Training Loss step:227-MSE:17.982620239257812
# Epoch: 29, Training Loss step:228-MSE:8.778822898864746
# Epoch: 29, Training Loss step:229-MSE:8.227216720581055
# Epoch: 29, Training Loss step:230-MSE:11.993581771850586
# Epoch: 29, Training Loss step:231-MSE:5.6757001876831055
# Epoch: 29, Training Loss step:232-MSE:13.63891887664795
# Epoch: 30, Training Loss step:233-MSE:10.82728385925293
# Epoch: 30, Training Loss step:234-MSE:7.904050827026367
# Epoch: 30, Training Loss step:235-MSE:11.566506385803223
# Epoch: 30, Training Loss step:236-MSE:9.059795379638672
# Epoch: 30, Training Loss step:237-MSE:11.601411819458008
# Epoch: 30, Training Loss step:238-MSE:6.524554252624512
# Epoch: 30, Training Loss step:239-MSE:8.171919822692871
# Epoch: 30, Training Loss step:240-MSE:9.793120384216309
# Epoch: 31, Training Loss step:241-MSE:7.280057907104492
# Epoch: 31, Training Loss step:242-MSE:9.506830215454102
# Epoch: 31, Training Loss step:243-MSE:10.960336685180664
# Epoch: 81, Training Loss step:645-MSE:4.663547992706299
# Epoch: 81, Training Loss step:646-MSE:8.127025604248047
# Epoch: 81, Training Loss step:647-MSE:7.319398403167725
# Epoch: 81, Training Loss step:648-MSE:4.866767883300781
# Epoch: 82, Training Loss step:649-MSE:4.376537799835205
# Epoch: 82, Training Loss step:650-MSE:4.965269565582275
# Epoch: 82, Training Loss step:651-MSE:9.114481925964355
# Epoch: 82, Training Loss step:652-MSE:5.059473037719727
# Epoch: 82, Training Loss step:653-MSE:5.599940299987793
# Epoch: 82, Training Loss step:654-MSE:1.6921663284301758
# Epoch: 82, Training Loss step:655-MSE:4.604310989379883
# Epoch: 82, Training Loss step:656-MSE:5.298050403594971
# Epoch: 83, Training Loss step:657-MSE:2.970961093902588
# Epoch: 83, Training Loss step:658-MSE:5.876471519470215
# Epoch: 83, Training Loss step:659-MSE:7.628726005554199
# Epoch: 83, Training Loss step:660-MSE:3.257054567337036
# Epoch: 83, Training Loss step:661-MSE:1.816819667816162
# Epoch: 83, Training Loss step:662-MSE:2.802435874938965
# Epoch: 83, Training Loss step:663-MSE:9.27542495727539
# Epoch: 83, Training Loss step:664-MSE:4.64817476272583
# Epoch: 84, Training Loss step:665-MSE:1.4444550275802612
# Epoch: 84, Training Loss step:666-MSE:3.0736465454101562
# Epoch: 84, Training Loss step:667-MSE:3.668409824371338
# Epoch: 84, Training Loss step:668-MSE:10.301957130432129
# Epoch: 84, Training Loss step:669-MSE:3.095198631286621
# Epoch: 84, Training Loss step:670-MSE:6.481666564941406
# Epoch: 84, Training Loss step:671-MSE:5.590374946594238
# Epoch: 84, Training Loss step:672-MSE:3.928105354309082
# Epoch: 85, Training Loss step:673-MSE:2.769155502319336
# Epoch: 85, Training Loss step:674-MSE:5.252719879150391
# Epoch: 85, Training Loss step:675-MSE:1.5198698043823242
# Epoch: 85, Training Loss step:676-MSE:3.7865567207336426
# Epoch: 85, Training Loss step:677-MSE:3.719619035720825
# Epoch: 85, Training Loss step:678-MSE:4.504193305969238
# Epoch: 85, Training Loss step:679-MSE:12.58413314819336
# Epoch: 85, Training Loss step:680-MSE:2.118533134460449
# Epoch: 86, Training Loss step:681-MSE:7.532777309417725
# Epoch: 86, Training Loss step:682-MSE:12.432937622070312
# Epoch: 86, Training Loss step:683-MSE:0.7366541028022766
# Epoch: 86, Training Loss step:684-MSE:5.068079471588135
# Epoch: 86, Training Loss step:685-MSE:2.1529507637023926
# Epoch: 86, Training Loss step:686-MSE:6.6908745765686035
# Epoch: 86, Training Loss step:687-MSE:5.672511577606201
# Epoch: 86, Training Loss step:688-MSE:5.561810493469238
# Epoch: 87, Training Loss step:689-MSE:9.311774253845215
# Epoch: 87, Training Loss step:690-MSE:1.4954922199249268
# Epoch: 87, Training Loss step:691-MSE:8.07874870300293
# Epoch: 87, Training Loss step:692-MSE:3.5695409774780273
# Epoch: 87, Training Loss step:693-MSE:2.8681721687316895
# Epoch: 87, Training Loss step:694-MSE:5.160421848297119
# Epoch: 106, Training Loss step:844-MSE:3.388742685317993
# Epoch: 106, Training Loss step:845-MSE:4.644355297088623
# Epoch: 106, Training Loss step:846-MSE:12.131562232971191
# Epoch: 106, Training Loss step:847-MSE:3.8629181385040283
# Epoch: 106, Training Loss step:848-MSE:5.1031317710876465
# Epoch: 107, Training Loss step:849-MSE:2.5889906883239746
# Epoch: 107, Training Loss step:850-MSE:4.7102532386779785
# Epoch: 107, Training Loss step:851-MSE:1.0756725072860718
# Epoch: 107, Training Loss step:852-MSE:1.438637614250183
# Epoch: 107, Training Loss step:853-MSE:10.837562561035156
# Epoch: 107, Training Loss step:854-MSE:1.3865102529525757
# ...
# Epoch: 467, Training Loss step:3731-MSE:1.2787859439849854
# Epoch: 467, Training Loss step:3732-MSE:0.24596571922302246
# Epoch: 467, Training Loss step:3733-MSE:0.15121586620807648
# Epoch: 467, Training Loss step:3734-MSE:0.3922538757324219
# Epoch: 467, Training Loss step:3735-MSE:1.7473912239074707
# Epoch: 467, Training Loss step:3736-MSE:0.34836769104003906
# Epoch: 468, Training Loss step:3737-MSE:0.11609333008527756
# Epoch: 468, Training Loss step:3738-MSE:2.472792863845825
# Epoch: 468, Training Loss step:3739-MSE:0.8938826322555542
# Epoch: 468, Training Loss step:3740-MSE:0.7857640385627747
# Epoch: 468, Training Loss step:3741-MSE:0.7901962995529175
# Epoch: 468, Training Loss step:3742-MSE:0.5194035172462463
# Epoch: 468, Training Loss step:3743-MSE:0.22814986109733582
# Epoch: 468, Training Loss step:3744-MSE:0.4106671214103699
# Epoch: 469, Training Loss step:3745-MSE:3.1324918270111084
# Epoch: 469, Training Loss step:3746-MSE:0.8501520156860352
# Epoch: 469, Training Loss step:3747-MSE:0.5695956945419312
# Epoch: 469, Training Loss step:3748-MSE:0.7439541816711426
# Epoch: 469, Training Loss step:3749-MSE:0.3444433808326721
# Epoch: 469, Training Loss step:3750-MSE:0.421599805355072
# Epoch: 469, Training Loss step:3751-MSE:0.3358004093170166
# Epoch: 469, Training Loss step:3752-MSE:1.238236904144287
# Epoch: 470, Training Loss step:3753-MSE:0.42816561460494995
# Epoch: 470, Training Loss step:3754-MSE:1.242162823677063
# Epoch: 470, Training Loss step:3755-MSE:0.6839156150817871
# Epoch: 470, Training Loss step:3756-MSE:0.42118045687675476
# Epoch: 470, Training Loss step:3757-MSE:0.2574685215950012
# Epoch: 470, Training Loss step:3758-MSE:0.6862055659294128
# Epoch: 470, Training Loss step:3759-MSE:0.1828676462173462
# Epoch: 470, Training Loss step:3760-MSE:0.8441685438156128
# Epoch: 471, Training Loss step:3761-MSE:0.28714004158973694
# Epoch: 471, Training Loss step:3762-MSE:0.5495188236236572
# Epoch: 471, Training Loss step:3763-MSE:0.8552165031433105
# Epoch: 471, Training Loss step:3764-MSE:0.6092193126678467
# Epoch: 471, Training Loss step:3765-MSE:3.3683440685272217
# Epoch: 471, Training Loss step:3766-MSE:0.3072569966316223
# Epoch: 471, Training Loss step:3767-MSE:0.26066428422927856
# Epoch: 471, Training Loss step:3768-MSE:0.7581292390823364
# Epoch: 472, Training Loss step:3769-MSE:1.0256824493408203
# Epoch: 472, Training Loss step:3770-MSE:0.3269536793231964
# Epoch: 472, Training Loss step:3771-MSE:2.459078550338745
# Epoch: 472, Training Loss step:3772-MSE:0.497417151927948
# Epoch: 472, Training Loss step:3773-MSE:0.4050522446632385
# Epoch: 472, Training Loss step:3774-MSE:0.3377722501754761
# Epoch: 472, Training Loss step:3775-MSE:0.7794094681739807
# Epoch: 472, Training Loss step:3776-MSE:0.45962196588516235
# Epoch: 473, Training Loss step:3777-MSE:0.44468873739242554
# Epoch: 473, Training Loss step:3778-MSE:0.21109527349472046
# Epoch: 473, Training Loss step:3779-MSE:1.3139309883117676
# Epoch: 473, Training Loss step:3780-MSE:0.9057979583740234
# Epoch: 473, Training Loss step:3781-MSE:0.33952969312667847
# Epoch: 473, Training Loss step:3782-MSE:0.7679049968719482
# Epoch: 473, Training Loss step:3783-MSE:0.6730602979660034
# Epoch: 473, Training Loss step:3784-MSE:1.2181994915008545
# Epoch: 474, Training Loss step:3785-MSE:0.45673349499702454
# Epoch: 474, Training Loss step:3786-MSE:2.1784603595733643
# Epoch: 474, Training Loss step:3787-MSE:0.4222757816314697
# Epoch: 474, Training Loss step:3788-MSE:1.0946390628814697
# Epoch: 474, Training Loss step:3789-MSE:0.4785926938056946
# Epoch: 474, Training Loss step:3790-MSE:0.6499185562133789
# Epoch: 474, Training Loss step:3791-MSE:0.6740239858627319
# Epoch: 474, Training Loss step:3792-MSE:0.512134313583374
# Epoch: 475, Training Loss step:3793-MSE:0.7157953977584839
# Epoch: 475, Training Loss step:3794-MSE:1.3803058862686157
# Epoch: 475, Training Loss step:3795-MSE:1.1092947721481323
# Epoch: 475, Training Loss step:3796-MSE:0.7215622663497925
# Epoch: 475, Training Loss step:3797-MSE:0.12528403103351593
# Epoch: 475, Training Loss step:3798-MSE:0.8487861752510071
# Epoch: 475, Training Loss step:3799-MSE:0.23260697722434998
# Epoch: 475, Training Loss step:3800-MSE:0.36345911026000977
# Epoch: 476, Training Loss step:3801-MSE:0.2974744141101837
# Epoch: 476, Training Loss step:3802-MSE:3.7174205780029297
# Epoch: 476, Training Loss step:3803-MSE:0.2927135229110718
# Epoch: 476, Training Loss step:3804-MSE:1.1443403959274292
# Epoch: 476, Training Loss step:3805-MSE:0.9813292622566223
# Epoch: 476, Training Loss step:3806-MSE:1.1719458103179932
# Epoch: 476, Training Loss step:3807-MSE:1.1292567253112793
# Epoch: 476, Training Loss step:3808-MSE:0.27044594287872314
# Epoch: 477, Training Loss step:3809-MSE:0.4235474467277527
# Epoch: 477, Training Loss step:3810-MSE:0.8997046947479248
# Epoch: 477, Training Loss step:3811-MSE:0.5455854535102844
# Epoch: 477, Training Loss step:3812-MSE:0.2223021239042282
# Epoch: 477, Training Loss step:3813-MSE:0.27798983454704285
# Epoch: 477, Training Loss step:3814-MSE:0.5175297260284424
# Epoch: 477, Training Loss step:3815-MSE:2.9078633785247803
# Epoch: 477, Training Loss step:3816-MSE:0.19054511189460754
# Epoch: 478, Training Loss step:3817-MSE:0.5148749351501465
# Epoch: 478, Training Loss step:3818-MSE:1.6105505228042603
# Epoch: 478, Training Loss step:3819-MSE:2.2207138538360596
# Epoch: 478, Training Loss step:3820-MSE:0.3917604684829712
# Epoch: 478, Training Loss step:3821-MSE:0.6182904243469238
# Epoch: 478, Training Loss step:3822-MSE:1.06378972530365
# Epoch: 478, Training Loss step:3823-MSE:1.0054675340652466
# Epoch: 478, Training Loss step:3824-MSE:0.1995617151260376
# Epoch: 479, Training Loss step:3825-MSE:0.5403302907943726
# Epoch: 479, Training Loss step:3826-MSE:0.8780184388160706
# Epoch: 479, Training Loss step:3827-MSE:0.25738948583602905
# Epoch: 479, Training Loss step:3828-MSE:0.7874961495399475
# Epoch: 479, Training Loss step:3829-MSE:1.5781409740447998
# Epoch: 479, Training Loss step:3830-MSE:0.37596461176872253
# Epoch: 479, Training Loss step:3831-MSE:0.5737324953079224
# Epoch: 479, Training Loss step:3832-MSE:2.784432888031006
# Epoch: 480, Training Loss step:3833-MSE:0.8303366303443909
# Epoch: 480, Training Loss step:3834-MSE:0.47724318504333496
# Epoch: 480, Training Loss step:3835-MSE:0.6455749273300171
# Epoch: 480, Training Loss step:3836-MSE:0.5161274075508118
# Epoch: 480, Training Loss step:3837-MSE:0.4265727996826172
# Epoch: 480, Training Loss step:3838-MSE:2.8432841300964355
# Epoch: 480, Training Loss step:3839-MSE:0.15527412295341492
# Epoch: 480, Training Loss step:3840-MSE:1.004622220993042
# Epoch: 481, Training Loss step:3841-MSE:4.223099708557129
# Epoch: 481, Training Loss step:3842-MSE:0.6556788086891174
# Epoch: 481, Training Loss step:3843-MSE:0.4654044508934021
# Epoch: 481, Training Loss step:3844-MSE:0.8180640935897827
# Epoch: 481, Training Loss step:3845-MSE:0.2068907618522644
# Epoch: 481, Training Loss step:3846-MSE:0.6626042127609253
# Epoch: 481, Training Loss step:3847-MSE:0.46264412999153137
# Epoch: 481, Training Loss step:3848-MSE:0.22781872749328613
# Epoch: 482, Training Loss step:3849-MSE:0.37352636456489563
# Epoch: 482, Training Loss step:3850-MSE:1.2895655632019043
# Epoch: 482, Training Loss step:3851-MSE:0.8034248352050781
# Epoch: 482, Training Loss step:3852-MSE:1.3761906623840332
# Epoch: 482, Training Loss step:3853-MSE:0.5240565538406372
# Epoch: 482, Training Loss step:3854-MSE:0.7247433066368103
# Epoch: 482, Training Loss step:3855-MSE:0.6843207478523254
# Epoch: 482, Training Loss step:3856-MSE:0.29355567693710327
# Epoch: 483, Training Loss step:3857-MSE:1.5710307359695435
# Epoch: 483, Training Loss step:3858-MSE:0.3120419979095459
# Epoch: 483, Training Loss step:3859-MSE:0.7397370934486389
# Epoch: 483, Training Loss step:3860-MSE:1.255820393562317
# Epoch: 483, Training Loss step:3861-MSE:0.5337601900100708
# Epoch: 483, Training Loss step:3862-MSE:0.8706821203231812
# Epoch: 483, Training Loss step:3863-MSE:0.42786848545074463
# Epoch: 483, Training Loss step:3864-MSE:0.5303075313568115
# Epoch: 484, Training Loss step:3865-MSE:0.311792254447937
# Epoch: 484, Training Loss step:3866-MSE:0.7431694865226746
# Epoch: 484, Training Loss step:3867-MSE:0.5429928302764893
# Epoch: 484, Training Loss step:3868-MSE:0.629877507686615
# Epoch: 484, Training Loss step:3869-MSE:0.7232314348220825
# Epoch: 484, Training Loss step:3870-MSE:0.2451353371143341
# Epoch: 484, Training Loss step:3871-MSE:1.3379395008087158
# Epoch: 484, Training Loss step:3872-MSE:1.149428129196167
# Epoch: 485, Training Loss step:3873-MSE:0.2675448954105377
# Epoch: 485, Training Loss step:3874-MSE:0.9930406808853149
# Epoch: 485, Training Loss step:3875-MSE:0.7178462147712708
# Epoch: 485, Training Loss step:3876-MSE:1.4549195766448975
# Epoch: 485, Training Loss step:3877-MSE:1.4883918762207031
# Epoch: 485, Training Loss step:3878-MSE:0.4040234088897705
# Epoch: 485, Training Loss step:3879-MSE:0.7535037398338318
# Epoch: 485, Training Loss step:3880-MSE:0.1733306497335434
# Epoch: 486, Training Loss step:3881-MSE:1.6126986742019653
# Epoch: 486, Training Loss step:3882-MSE:0.35896000266075134
# Epoch: 486, Training Loss step:3883-MSE:0.9760180711746216
# Epoch: 486, Training Loss step:3884-MSE:0.2871015667915344
# Epoch: 486, Training Loss step:3885-MSE:0.51502525806427
# Epoch: 486, Training Loss step:3886-MSE:0.3563217222690582
# Epoch: 486, Training Loss step:3887-MSE:0.20754395425319672
# Epoch: 486, Training Loss step:3888-MSE:1.1020314693450928
# Epoch: 487, Training Loss step:3889-MSE:0.32675623893737793
# Epoch: 487, Training Loss step:3890-MSE:0.9674829840660095
# Epoch: 487, Training Loss step:3891-MSE:1.1410884857177734
# Epoch: 487, Training Loss step:3892-MSE:0.27069610357284546
# Epoch: 487, Training Loss step:3893-MSE:0.3352959156036377
# Epoch: 487, Training Loss step:3894-MSE:0.5072512626647949
# Epoch: 487, Training Loss step:3895-MSE:0.46414875984191895
# Epoch: 487, Training Loss step:3896-MSE:1.2286598682403564
# Epoch: 488, Training Loss step:3897-MSE:0.5348700284957886
# Epoch: 488, Training Loss step:3898-MSE:0.4664105474948883
# Epoch: 488, Training Loss step:3899-MSE:0.21461701393127441
# Epoch: 488, Training Loss step:3900-MSE:0.3048332631587982
# Epoch: 488, Training Loss step:3901-MSE:0.3367958068847656
# Epoch: 488, Training Loss step:3902-MSE:1.0687124729156494
# Epoch: 488, Training Loss step:3903-MSE:0.7185438275337219
# Epoch: 488, Training Loss step:3904-MSE:2.018930673599243
# Epoch: 489, Training Loss step:3905-MSE:0.36840641498565674
# Epoch: 489, Training Loss step:3906-MSE:0.30446887016296387
# Epoch: 489, Training Loss step:3907-MSE:0.1747538447380066
# Epoch: 489, Training Loss step:3908-MSE:0.4978652894496918
# Epoch: 489, Training Loss step:3909-MSE:0.11376425623893738
# Epoch: 489, Training Loss step:3910-MSE:0.6676459312438965
# Epoch: 489, Training Loss step:3911-MSE:2.1441574096679688
# Epoch: 489, Training Loss step:3912-MSE:0.9231343865394592
# Epoch: 490, Training Loss step:3913-MSE:0.5394772291183472
# Epoch: 490, Training Loss step:3914-MSE:0.4562820792198181
# Epoch: 490, Training Loss step:3915-MSE:1.4917056560516357
# Epoch: 490, Training Loss step:3916-MSE:0.5365237593650818
# Epoch: 490, Training Loss step:3917-MSE:0.21918770670890808
# Epoch: 490, Training Loss step:3918-MSE:0.2500934898853302
# Epoch: 490, Training Loss step:3919-MSE:0.3915010690689087
# Epoch: 490, Training Loss step:3920-MSE:0.21530866622924805
# Epoch: 491, Training Loss step:3921-MSE:1.3038175106048584
# Epoch: 491, Training Loss step:3922-MSE:0.7883263826370239
# Epoch: 491, Training Loss step:3923-MSE:0.3852921426296234
# Epoch: 491, Training Loss step:3924-MSE:0.36527830362319946
# Epoch: 491, Training Loss step:3925-MSE:0.18897242844104767
# Epoch: 491, Training Loss step:3926-MSE:0.49047785997390747
# Epoch: 491, Training Loss step:3927-MSE:2.3082468509674072
# Epoch: 491, Training Loss step:3928-MSE:2.1289806365966797
# Epoch: 492, Training Loss step:3929-MSE:0.4448404908180237
# Epoch: 492, Training Loss step:3930-MSE:0.8786494731903076
# Epoch: 492, Training Loss step:3931-MSE:0.5365878343582153
# Epoch: 492, Training Loss step:3932-MSE:0.6818640828132629
# Epoch: 492, Training Loss step:3933-MSE:0.34969189763069153
# Epoch: 492, Training Loss step:3934-MSE:1.8375331163406372
# Epoch: 492, Training Loss step:3935-MSE:0.9448007345199585
# Epoch: 492, Training Loss step:3936-MSE:0.31720292568206787
# Epoch: 493, Training Loss step:3937-MSE:0.21038827300071716
# Epoch: 493, Training Loss step:3938-MSE:0.7824826240539551
# Epoch: 493, Training Loss step:3939-MSE:0.1692669689655304
# Epoch: 493, Training Loss step:3940-MSE:0.5918867588043213
# Epoch: 493, Training Loss step:3941-MSE:0.5531404614448547
# Epoch: 493, Training Loss step:3942-MSE:0.24562381207942963
# Epoch: 493, Training Loss step:3943-MSE:4.054327487945557
# Epoch: 493, Training Loss step:3944-MSE:1.0381933450698853
# Epoch: 494, Training Loss step:3945-MSE:0.24368099868297577
# Epoch: 494, Training Loss step:3946-MSE:0.34801745414733887
# Epoch: 494, Training Loss step:3947-MSE:0.5027643442153931
# Epoch: 494, Training Loss step:3948-MSE:1.680288314819336
# Epoch: 494, Training Loss step:3949-MSE:0.21007460355758667
# Epoch: 494, Training Loss step:3950-MSE:0.3084842562675476
# Epoch: 494, Training Loss step:3951-MSE:0.7335855960845947
# Epoch: 494, Training Loss step:3952-MSE:1.8272695541381836
# Epoch: 495, Training Loss step:3953-MSE:0.27384525537490845
# Epoch: 495, Training Loss step:3954-MSE:0.6790181994438171
# Epoch: 495, Training Loss step:3955-MSE:0.5121653079986572
# Epoch: 495, Training Loss step:3956-MSE:2.0244319438934326
# Epoch: 495, Training Loss step:3957-MSE:0.438889741897583
# Epoch: 495, Training Loss step:3958-MSE:1.0201995372772217
# Epoch: 495, Training Loss step:3959-MSE:0.10171662271022797
# Epoch: 495, Training Loss step:3960-MSE:1.067061185836792
# Epoch: 496, Training Loss step:3961-MSE:0.3058452904224396
# Epoch: 496, Training Loss step:3962-MSE:0.44364386796951294
# Epoch: 496, Training Loss step:3963-MSE:0.3092074990272522
# Epoch: 496, Training Loss step:3964-MSE:0.5777135491371155
# Epoch: 496, Training Loss step:3965-MSE:0.7448832392692566
# Epoch: 496, Training Loss step:3966-MSE:0.4860090911388397
# Epoch: 496, Training Loss step:3967-MSE:0.568827211856842
# Epoch: 496, Training Loss step:3968-MSE:2.8712306022644043
# Epoch: 497, Training Loss step:3969-MSE:0.24911101162433624
# Epoch: 497, Training Loss step:3970-MSE:0.3070160746574402
# Epoch: 497, Training Loss step:3971-MSE:2.3733177185058594
# Epoch: 497, Training Loss step:3972-MSE:0.8351311683654785
# Epoch: 497, Training Loss step:3973-MSE:0.13720381259918213
# Epoch: 497, Training Loss step:3974-MSE:0.7398592829704285
# Epoch: 497, Training Loss step:3975-MSE:0.10306805372238159
# Epoch: 497, Training Loss step:3976-MSE:0.8563517332077026
# Epoch: 498, Training Loss step:3977-MSE:1.5476264953613281
# Epoch: 498, Training Loss step:3978-MSE:0.9842962622642517
# Epoch: 498, Training Loss step:3979-MSE:0.25064772367477417
# Epoch: 498, Training Loss step:3980-MSE:0.25608697533607483
# Epoch: 498, Training Loss step:3981-MSE:0.354808509349823
# Epoch: 498, Training Loss step:3982-MSE:1.0981742143630981
# Epoch: 498, Training Loss step:3983-MSE:0.4776332378387451
# Epoch: 498, Training Loss step:3984-MSE:0.837489128112793
# Epoch: 499, Training Loss step:3985-MSE:0.7073304653167725
# Epoch: 499, Training Loss step:3986-MSE:0.39495229721069336
# Epoch: 499, Training Loss step:3987-MSE:1.476637601852417
# Epoch: 499, Training Loss step:3988-MSE:0.30083537101745605
# Epoch: 499, Training Loss step:3989-MSE:1.630852222442627
# Epoch: 499, Training Loss step:3990-MSE:0.35481780767440796
# Epoch: 499, Training Loss step:3991-MSE:0.9719784259796143
# Epoch: 499, Training Loss step:3992-MSE:1.6534662246704102
# Epoch: 500, Training Loss step:3993-MSE:0.28597962856292725
# Epoch: 500, Training Loss step:3994-MSE:0.2039661407470703
# Epoch: 500, Training Loss step:3995-MSE:1.0166292190551758
# Epoch: 500, Training Loss step:3996-MSE:0.7281594276428223
# Epoch: 500, Training Loss step:3997-MSE:0.46390095353126526
# Epoch: 500, Training Loss step:3998-MSE:0.6630778908729553
# Epoch: 500, Training Loss step:3999-MSE:0.21808740496635437
# Epoch: 500, Training Loss step:4000-MSE:0.4972453713417053

# %%
# loss_list may contain CUDA tensors → turn each into a Python float
loss_cpu_training = [float(l.detach().cpu()) if torch.is_tensor(l) else float(l)
            for l in training_loss]

# ── basic curve ─────────────────────────────────────────────────────────
# plt.figure(figsize=(8, 5))
# plt.plot(loss_cpu_training, label='Training loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss (MSE)')
# plt.title('Training loss vs. epoch')
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

# # ── optional: add a 5‑epoch rolling‑average smoother ───────────────────
smooth = pd.Series(loss_cpu_training).rolling(window=5, min_periods=1).mean()
plt.figure(figsize=(8, 5))
plt.plot(loss_cpu_training,  alpha=0.3, label='Raw')
plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# loss_list may contain CUDA tensors → turn each into a Python float
loss_cpu_val = [float(l.detach().cpu()) if torch.is_tensor(l) else float(l)
            for l in val_loss_list]

# ── basic curve ─────────────────────────────────────────────────────────
# plt.figure(figsize=(8, 5))
# plt.plot(loss_cpu_training, label='Training loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss (MSE)')
# plt.title('Training loss vs. epoch')
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

# # ── optional: add a 5‑epoch rolling‑average smoother ───────────────────
smooth = pd.Series(loss_cpu_val).rolling(window=5, min_periods=1).mean()
plt.figure(figsize=(8, 5))
plt.plot(loss_cpu_val,  alpha=0.3, label='Raw')
plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
loss_cpu_val
# Out:
# [95.0739974975586,
#  88.83580017089844,
#  77.83186340332031,
#  61.019935607910156,
#  41.58246994018555,
#  31.549428939819336,
#  33.401790618896484,
#  30.776840209960938,
#  26.10071563720703,
#  25.879093170166016,
#  26.44583511352539,
#  26.915077209472656,
#  25.647308349609375,
#  26.976638793945312,
#  26.369571685791016,
#  24.51609230041504,
#  23.76934051513672,
#  24.002910614013672,
#  23.715435028076172,
#  22.870147705078125,
#  25.000377655029297,
#  22.747310638427734,
#  22.43655014038086,
#  23.183401107788086,
#  20.536846160888672,
#  20.487598419189453,
#  19.727144241333008,
#  21.14854621887207,
#  19.33881950378418,
#  20.74704360961914,
#  20.51238441467285,
#  18.810379028320312,
#  19.30980682373047,
#  19.609819412231445,
#  18.697921752929688,
#  17.503128051757812,
#  18.61762237548828,
#  17.63898468017578,
#  17.51483917236328,
#  15.678346633911133,
#  16.916723251342773,
#  17.45862579345703,
#  16.774858474731445,
#  16.408212661743164,
#  19.62796974182129,
#  18.427146911621094,
#  16.688093185424805,
#  16.112579345703125,
#  17.914836883544922,
#  16.566490173339844,
#  15.179595947265625,
#  15.725088119506836,
#  16.672082901000977,
#  15.649709701538086,
#  14.466580390930176,
#  15.45297622680664,
#  15.012744903564453,
#  14.934900283813477,
#  14.208330154418945,
#  15.034832000732422,
#  15.44339370727539,
#  14.565959930419922,
#  14.500476837158203,
#  15.555904388427734,
#  14.784069061279297,
#  14.394580841064453,
#  14.819620132446289,
#  14.306426048278809,
#  13.6191987991333,
#  15.051700592041016,
#  13.928047180175781,
#  13.500249862670898,
#  13.90029525756836,
#  12.972663879394531,
#  13.65667724609375,
#  15.175804138183594,
#  12.68925952911377,
#  12.608911514282227,
#  13.023983001708984,
#  13.924206733703613,
#  14.285219192504883,
#  15.122560501098633,
#  14.529335021972656,
#  2.563660144805908,
#  4.215493202209473,
#  3.476889133453369,
#  3.2989397048950195,
#  3.317049503326416,
#  3.821877956390381,
#  2.5168535709381104,
#  2.758349657058716,
#  2.746126174926758,
#  3.256720542907715]

# %%
# model.load_state_dict(best_state)

# ── 4.  Evaluate on the test set ─────────────────────────────────────────
model.eval()
with torch.no_grad():
    preds_z = model(X_test_t.to(device)).cpu().numpy().ravel()

#preds = y_scaler.inverse_transform(preds_z.reshape(-1, 1)).ravel()

rmse_nn = np.sqrt(mean_squared_error(y_test_flood, preds_z))
r2_nn   = r2_score(y_test_flood, preds)

print(f"PyTorch NN  RMSE: {rmse_nn:,.2f}   R²: {r2_nn:.3f}")

# ── 5.  Add to your results list ─────────────────────────────────────────
results_tornado.append({
    "Model": "Neural Network (PyTorch, Tornado)",
    "RMSE":  rmse_nn,
    "R² Score": r2_nn
})
# Out:
# PyTorch NN  RMSE: 0.35   R²: 0.984

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(preds_z,  label='Predicted Value')
plt.ylim(-20, 30)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# at the end of training, after your loop:
torch.save(model.state_dict(), "Models/mlp_regressor_state_dict_flash_flood.pth")

# %% [markdown]
# # XGA Boost Regressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
X_train_scaled_flood
# Out:
#      injuries_direct  deaths_direct  event_latitude  event_longitude  \
# 240        -0.572694      -0.288569        1.324625         0.911505
# 358        -0.572694      -0.288569        0.656417         0.159379
# 199        -0.572694       3.519353        0.326089         0.325986
# 185        -0.572694       0.187421        0.334766         0.321716
# 283         2.045336       0.187421        0.982768         0.713096
# ..               ...            ...             ...              ...
# 267         0.736321      -0.764559       -1.883200         1.231411
# 175        -0.572694      -0.288569        0.507328        -0.152588
# 253        -0.572694      -0.288569       -1.846203         1.215892
# 340        -0.572694      -0.288569        0.601564        -1.927852
# 263         0.736321      -0.764559       -1.867266         1.255552
#
#      event_range  event_duration  source_911 Call Center  \
# 240    -0.031148       -0.474939               -0.197386
# 358    -0.102132       -0.588205               -0.197386
# 199     0.317858        1.677117               -0.197386
# 185    -0.421562        1.548749               -0.197386
# 283    -0.767610       -0.595756               -0.197386
# ..           ...             ...                     ...
# 267    -0.717329       -0.648614               -0.197386
# 175    -0.604938       -0.095497               -0.197386
# 253     0.028006        4.197287               -0.197386
# 340    -0.427477        1.788495               -0.197386
# 263    -0.468884       -0.582542               -0.197386
#
#      source_Broadcast Media  source_CoCoRaHS  source_County Official  \
# 240               -0.321634         7.234178               -0.258199
# 358               -0.321634        -0.138233               -0.258199
# 199               -0.321634        -0.138233               -0.258199
# 185               -0.321634        -0.138233                3.872983
# 283               -0.321634        -0.138233               -0.258199
# ..                      ...              ...                     ...
# 267               -0.321634        -0.138233               -0.258199
# 175               -0.321634        -0.138233               -0.258199
# 253               -0.321634        -0.138233               -0.258199
# 340               -0.321634        -0.138233               -0.258199
# 263               -0.321634        -0.138233               -0.258199
#
#      source_Emergency Manager  source_Fire Department/Rescue  \
# 240                 -0.625543                      -0.244137
# 358                  1.598611                      -0.244137
# 199                 -0.625543                      -0.244137
# 185                 -0.625543                      -0.244137
# 283                 -0.625543                      -0.244137
# ..                        ...                            ...
# 267                 -0.625543                      -0.244137
# 175                 -0.625543                      -0.244137
# 253                  1.598611                      -0.244137
# 340                 -0.625543                      -0.244137
# 263                 -0.625543                      -0.244137
#
#      source_Law Enforcement  source_NWS Storm Survey  \
# 240               -0.538816                -0.112509
# 358               -0.538816                -0.112509
# 199                1.855921                -0.112509
# 185               -0.538816                -0.112509
# 283               -0.538816                -0.112509
# ..                      ...                      ...
# 267               -0.538816                -0.112509
# 175                1.855921                -0.112509
# 253               -0.538816                -0.112509
# 340                1.855921                -0.112509
# 263               -0.538816                -0.112509
#
#      source_Other Federal Agency  source_Park/Forest Service  source_Public  \
# 240                    -0.179605                   -0.138233      -0.271708
# 358                    -0.179605                   -0.138233      -0.271708
# 199                    -0.179605                   -0.138233      -0.271708
# 185                    -0.179605                   -0.138233      -0.271708
# 283                    -0.179605                   -0.138233      -0.271708
# ..                           ...                         ...            ...
# 267                    -0.179605                   -0.138233      -0.271708
# 175                    -0.179605                   -0.138233      -0.271708
# 253                    -0.179605                   -0.138233      -0.271708
# 340                    -0.179605                   -0.138233      -0.271708
# 263                    -0.179605                   -0.138233      -0.271708
#
#      source_State Official
# 240              -0.321634
# 358              -0.321634
# 199              -0.321634
# 185              -0.321634
# 283               3.109126
# ..                     ...
# 267               3.109126
# 175              -0.321634
# 253              -0.321634
# 340              -0.321634
# 263               3.109126
#
# [160 rows x 18 columns]

# %%
xgb_model = XGBRegressor(
    n_estimators=800,        # total boosted trees
    learning_rate=0.03,     # shrinkage (η)
    max_depth=6,            # tree depth
    subsample=0.8,          # row sampling
    colsample_bytree=0.8,   # feature sampling
    objective="reg:squarederror",
    reg_lambda=1.0,         # L2 regularisation
    random_state=42,
    n_jobs=-1,              # use all CPU cores
)

# Optionally try a log‑target wrapper (similar to TransformedTargetRegressor)
# if you still have huge dynamic‑range issues.

xgb_model.fit(X_train_scaled_flood, y_train_flood)

y_pred_xgb = xgb_model.predict(X_test_scaled_flood)

rmse_xgb = np.sqrt(mean_squared_error(y_test_flood, y_pred_xgb))
r2_xgb   = r2_score(y_test_flood, y_pred_xgb)

print(f"XGBoost  RMSE: {rmse_xgb:,.2f}   R²: {r2_xgb:.3f}")


results_tornado.append({
    "Model": "XGBoost Regressor (Tornado)",
    "RMSE":  rmse_xgb,
    "R² Score": r2_xgb
})
# Out:
# XGBoost  RMSE: 0.56   R²: 0.992

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred_xgb,  label='Predicted Value')
plt.ylim(-20, 30)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
joblib.dump(xgb_model, "Models/xgb_tornado_flash_flood.joblib")
# Out:
# ['Models/xgb_tornado_flash_flood.joblib']

# %% [markdown]
# # Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from scipy.stats import loguniform
from sklearn.model_selection import RandomizedSearchCV

# %%
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("svr", SVR(kernel="rbf"))
])

svr_ttr = TransformedTargetRegressor(
    regressor=pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

svr_ttr.fit(X_train_scaled_flood, y_train_flood)
# Out:
# TransformedTargetRegressor(func=<ufunc 'log1p'>, inverse_func=<ufunc 'expm1'>,
#                            regressor=Pipeline(steps=[('scaler',
#                                                       StandardScaler()),
#                                                      ('svr', SVR())]))

# %%
y_pred = svr_ttr.predict(X_test_scaled_flood)     # already inverse‑transformed
rmse_svr   = np.sqrt(mean_squared_error(y_test_flood, y_pred))
r2_svr     = r2_score(y_test_flood, y_pred)

# %%
print(f"SVR  RMSE: {rmse_svr:,.2f}   R²: {r2_svr:.3f}")
# Out:
# SVR  RMSE: 4.09   R²: 0.585

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred,  label='Predicted Value')
plt.ylim(-20, 40)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
joblib.dump(svr_ttr, "Models/svr_pipeline_flash_floods.joblib")
# Out:
# ['Models/svr_pipeline_flash_floods.joblib']

# %% [markdown]
# # Adaboost Regressor

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
ada_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("ada", AdaBoostRegressor(
        n_estimators=100,
        learning_rate=0.1,
        random_state=42
    )),
])

ada_ttr = TransformedTargetRegressor(
    regressor=ada_pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

ada_ttr.fit(X_train_scaled_flood, y_train_flood)
y_pred_ada = ada_ttr.predict(X_test_scaled_flood)   # inverse‑transformed
rmse_ada = np.sqrt(mean_squared_error(y_test_flood, y_pred_ada))
r2_ada   = r2_score(y_test_flood, y_pred_ada)

print(f"AdaBoost   RMSE: {rmse_ada:.2f}   R²: {r2_ada:.3f}")
# Out:
# AdaBoost   RMSE: 3.51   R²: 0.696

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred_ada,  label='Predicted Value')
plt.ylim(-20, 40)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
joblib.dump(ada_ttr, "Models/ada_pipeline_flash_floods.joblib")
# Out:
# ['Models/ada_pipeline_flash_floods.joblib']

# %% [markdown]
# # KNN Regressor

# %%
knn_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsRegressor(
        n_neighbors=5,
        weights="uniform",
        n_jobs=-1
    )),
])

knn_ttr = TransformedTargetRegressor(
    regressor=knn_pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

knn_ttr.fit(X_train_scaled_flood, y_train_flood)
y_pred_knn = knn_ttr.predict(X_test_scaled_flood)  # inverse‑transformed
rmse_knn = np.sqrt(mean_squared_error(y_test_flood, y_pred_knn))
r2_knn   = r2_score(y_test_flood, y_pred_knn)

print(f"KNN        RMSE: {rmse_knn:.2f}   R²: {r2_knn:.3f}")
# Out:
# KNN        RMSE: 3.84   R²: 0.636

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred_knn,  label='Predicted Value')
plt.ylim(-20, 40)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
