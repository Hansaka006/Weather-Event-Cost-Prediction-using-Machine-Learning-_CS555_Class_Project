# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import learning_curve
from sklearn.pipeline import make_pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import FunctionTransformer
from pandas.plotting import scatter_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import matplotlib.pyplot as plt

# %%
# Load the dataset
file_path = "dataset_source.csv"
df = pd.read_csv(file_path)

# Display basic information and the first few rows
df_info = df.info()
df_head = df.head()


df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   injuries_direct   761 non-null    int64
#  1   deaths_direct     761 non-null    int64
#  2   event_latitude    761 non-null    float64
#  3   event_longitude   761 non-null    float64
#  4   event_range       761 non-null    float64
#  5   event_type        761 non-null    object
#  6   event_begin_time  761 non-null    object
#  7   event_end_time    761 non-null    object
#  8   damage_property   761 non-null    int64
#  9   source            761 non-null    object
#  10  rn                761 non-null    int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 65.5+ KB
#         injuries_direct  deaths_direct  event_latitude  event_longitude  \
# count        761.000000     761.000000      761.000000       761.000000
# unique              NaN            NaN             NaN              NaN
# top                 NaN            NaN             NaN              NaN
# freq                NaN            NaN             NaN              NaN
# mean           2.721419       0.629435       35.747277       -89.650005
# std            6.361370       1.299545        6.099935        17.587892
# min            0.000000       0.000000        7.360600      -124.120000
# 25%            0.000000       0.000000       33.000000       -97.096600
# 50%            1.000000       0.000000       36.180000       -89.150000
# 75%            2.000000       1.000000       39.087400       -81.810000
# max           88.000000       9.000000       48.270000       151.858900
#
#         event_range   event_type     event_begin_time       event_end_time  \
# count    761.000000          761                  761                  761
# unique          NaN            4                  449                  449
# top             NaN  flash flood  2024-07-10T21:30:00  2023-01-01T23:59:00
# freq            NaN          200                   10                   13
# mean       2.655440          NaN                  NaN                  NaN
# std        3.083233          NaN                  NaN                  NaN
# min        0.000000          NaN                  NaN                  NaN
# 25%        0.910000          NaN                  NaN                  NaN
# 50%        1.820000          NaN                  NaN                  NaN
# 75%        3.150000          NaN                  NaN                  NaN
# max       25.960000          NaN                  NaN                  NaN
#
#         damage_property            source          rn
# count      7.610000e+02               761  761.000000
# unique              NaN                30         NaN
# top                 NaN  NWS Storm Survey         NaN
# freq                NaN               223         NaN
# mean       1.545455e+07               NaN   96.374507
# std        1.071591e+08               NaN   56.148045
# min        0.000000e+00               NaN    1.000000
# 25%        0.000000e+00               NaN   48.000000
# 50%        1.500000e+04               NaN   96.000000
# 75%        8.500000e+05               NaN  143.000000
# max        1.800000e+09               NaN  200.000000

# %%
# Load the dataset
file_path = "dataset_source.csv"
df = pd.read_csv(file_path)

# Display basic information and the first few rows
df_info = df.info()
df_head = df.head()


df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   injuries_direct   761 non-null    int64
#  1   deaths_direct     761 non-null    int64
#  2   event_latitude    761 non-null    float64
#  3   event_longitude   761 non-null    float64
#  4   event_range       761 non-null    float64
#  5   event_type        761 non-null    object
#  6   event_begin_time  761 non-null    object
#  7   event_end_time    761 non-null    object
#  8   damage_property   761 non-null    int64
#  9   source            761 non-null    object
#  10  rn                761 non-null    int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 65.5+ KB
#         injuries_direct  deaths_direct  event_latitude  event_longitude  \
# count        761.000000     761.000000      761.000000       761.000000
# unique              NaN            NaN             NaN              NaN
# top                 NaN            NaN             NaN              NaN
# freq                NaN            NaN             NaN              NaN
# mean           2.721419       0.629435       35.747277       -89.650005
# std            6.361370       1.299545        6.099935        17.587892
# min            0.000000       0.000000        7.360600      -124.120000
# 25%            0.000000       0.000000       33.000000       -97.096600
# 50%            1.000000       0.000000       36.180000       -89.150000
# 75%            2.000000       1.000000       39.087400       -81.810000
# max           88.000000       9.000000       48.270000       151.858900
#
#         event_range   event_type     event_begin_time       event_end_time  \
# count    761.000000          761                  761                  761
# unique          NaN            4                  449                  449
# top             NaN  flash flood  2024-07-10T21:30:00  2023-01-01T23:59:00
# freq            NaN          200                   10                   13
# mean       2.655440          NaN                  NaN                  NaN
# std        3.083233          NaN                  NaN                  NaN
# min        0.000000          NaN                  NaN                  NaN
# 25%        0.910000          NaN                  NaN                  NaN
# 50%        1.820000          NaN                  NaN                  NaN
# 75%        3.150000          NaN                  NaN                  NaN
# max       25.960000          NaN                  NaN                  NaN
#
#         damage_property            source          rn
# count      7.610000e+02               761  761.000000
# unique              NaN                30         NaN
# top                 NaN  NWS Storm Survey         NaN
# freq                NaN               223         NaN
# mean       1.545455e+07               NaN   96.374507
# std        1.071591e+08               NaN   56.148045
# min        0.000000e+00               NaN    1.000000
# 25%        0.000000e+00               NaN   48.000000
# 50%        1.500000e+04               NaN   96.000000
# 75%        8.500000e+05               NaN  143.000000
# max        1.800000e+09               NaN  200.000000

# %%
# Convert time columns to datetime
df['event_begin_time'] = pd.to_datetime(df['event_begin_time'])
df['event_end_time'] = pd.to_datetime(df['event_end_time'])

# Calculate event_duration in minutes
df['event_duration'] = (df['event_end_time'] - df['event_begin_time']).dt.total_seconds() / 60

# Convert event_range to float (if not already)
df['event_range'] = df['event_range'].astype(float)

# Drop the 'rn' column
df.drop(columns=['rn'], inplace=True)

# One-hot encode 'event_type'
df = pd.get_dummies(df, columns=['event_type'], prefix='event')
df = pd.get_dummies(df, columns=['source'], prefix='source')

# %%
df.head()
# Out:
#    injuries_direct  deaths_direct  event_latitude  event_longitude  \
# 0                5              0         35.2174        -111.7912
# 1                5              0         35.1951        -111.7083
# 2                2              0         43.2988        -111.1497
# 3                4              0         43.3091        -111.1637
# 4                3              0         43.9100        -116.8100
#
#    event_range    event_begin_time      event_end_time  damage_property  \
# 0         2.36 2024-10-18 07:00:00 2024-10-18 07:10:00                0
# 1         3.31 2024-10-18 07:00:00 2024-10-18 07:10:00                0
# 2         5.00 2024-08-10 12:36:00 2024-08-10 12:50:00                0
# 3         4.00 2024-08-10 12:35:00 2024-08-10 12:45:00                0
# 4         4.18 2024-06-26 13:00:00 2024-06-26 13:10:00                0
#
#    event_duration  event_flash flood  ...  source_NWS Storm Survey  \
# 0            10.0              False  ...                    False
# 1            10.0              False  ...                    False
# 2            14.0              False  ...                    False
# 3            10.0              False  ...                    False
# 4            10.0              False  ...                    False
#
#    source_Newspaper  source_OFFICIAL NWS OBS.  source_Other Federal Agency  \
# 0             False                     False                        False
# 1             False                     False                        False
# 2             False                     False                        False
# 3             False                     False                        False
# 4             False                     False                        False
#
#    source_Park/Forest Service  source_Public  source_Social Media  \
# 0                       False          False                False
# 1                       False          False                False
# 2                       False           True                False
# 3                       False           True                False
# 4                       False          False                False
#
#    source_State Official  source_TRAINED SPOTTER  source_Trained Spotter
# 0                  False                   False                   False
# 1                  False                   False                   False
# 2                  False                   False                   False
# 3                  False                   False                   False
# 4                  False                   False                   False
#
# [5 rows x 43 columns]

# %%
df.columns.tolist()
# Out:
# ['injuries_direct',
#  'deaths_direct',
#  'event_latitude',
#  'event_longitude',
#  'event_range',
#  'event_begin_time',
#  'event_end_time',
#  'damage_property',
#  'event_duration',
#  'event_flash flood',
#  'event_hail',
#  'event_thunderstorm wind',
#  'event_tornado',
#  'source_911 Call Center',
#  'source_AMATEUR RADIO',
#  'source_ASOS',
#  'source_Amateur Radio',
#  'source_Broadcast Media',
#  'source_COOP Observer',
#  'source_CoCoRaHS',
#  'source_County Official',
#  'source_Department of Highways',
#  'source_EMERGENCY MANAGER',
#  'source_Emergency Manager',
#  'source_FIRE DEPT/RESCUE SQUAD',
#  'source_Fire Department/Rescue',
#  'source_GENERAL PUBLIC',
#  'source_LAW ENFORCEMENT',
#  'source_Law Enforcement',
#  'source_Local Official',
#  'source_NEWSPAPER',
#  'source_NWS Employee',
#  'source_NWS STORM SURVEY',
#  'source_NWS Storm Survey',
#  'source_Newspaper',
#  'source_OFFICIAL NWS OBS.',
#  'source_Other Federal Agency',
#  'source_Park/Forest Service',
#  'source_Public',
#  'source_Social Media',
#  'source_State Official',
#  'source_TRAINED SPOTTER',
#  'source_Trained Spotter']

# %% [markdown]
# # Data Visualization

# %%
# Filter for flash flood events
df_flashflood = df[df['event_hail'] == 1].copy()

source_cols = [col for col in df_flashflood.columns if col.startswith('source_')]

# Drop source columns that are all zeros for that row (i.e., retain only true sources)
df_flashflood_filtered = df_flashflood[df_flashflood[source_cols].sum(axis=1) > 0].copy()

# Now drop all event and irrelevant columns
X_flood = df_flashflood_filtered.drop(columns=[
    'damage_property',
    'event_begin_time',
    'event_end_time',
    'event_tornado',
    'event_hail',
    'event_flash flood',
    'event_thunderstorm wind'
] + [col for col in source_cols if df_flashflood_filtered[col].nunique() == 1 and df_flashflood_filtered[col].iloc[0] == 0])

df_flashflood['damage_property_log'] = np.log1p(df_flashflood['damage_property'])
y_flood = df_flashflood['damage_property_log']
# Prepare features and target
# X_flood = df_flashflood.drop(columns=['damage_property','event_begin_time', 'event_end_time', 'event_tornado', 'event_hail', 'event_flash flood', 'event_thunderstorm wind'])
#y_flood = df_flashflood['damage_property']
# y_flood = np.log1p(df_flashflood['damage_property'])  # to reduce scale issues

# Split and scale
X_train_flood, X_test_flood, y_train_flood, y_test_flood = train_test_split(X_flood, y_flood, test_size=0.2, random_state=42)
scaler = StandardScaler()
X_train_scaled_flood = pd.DataFrame(scaler.fit_transform(X_train_flood), columns=X_flood.columns, index=X_train_flood.index)
X_test_scaled_flood = pd.DataFrame(scaler.transform(X_test_flood), columns=X_flood.columns, index=X_test_flood.index)

# %% [markdown]
# Since, damage cost column contains values from 0 to 500000000. We convert the outcome into a log value and predict the log value

# %%
np.max(df_flashflood['damage_property'])
# Out:
# 1800000000

# %%
plt.figure(figsize=(8, 4))
plt.hist(df_flashflood['damage_property_log'], bins=200, edgecolor='k')
plt.xlabel('y value')
plt.ylabel('Frequency')
plt.title('Histogram of raw Damage Cost')
plt.tight_layout()
plt.show()

# %%
# Compute correlation matrix
corr_matrix = X_train_scaled_flood.corr()

# Plot heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Heatmap of Scaled Hail Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Linear Regression and Random Forest Regressor

# %%
# Initialize and train tornado models
tornado_models = {
    "Linear Regression (Hail)": LinearRegression(),
    "Random Forest Regressor (Hail)": RandomForestRegressor(n_estimators=100, random_state=42)
}

# Train, predict, and evaluate
results_tornado = []
for name, model in tornado_models.items():
    model.fit(X_train_scaled_flood, y_train_flood)
    preds = model.predict(X_test_scaled_flood)
    rmse_tornado = np.sqrt(mean_squared_error(y_test_flood, preds))
    r2_tornado = r2_score(y_test_flood, preds)
    results_tornado.append({
        "Model": name,
        "RMSE": rmse_tornado,
        "R² Score": r2_tornado
    })

# Show results
results_tornado_df = pd.DataFrame(results_tornado)
print(results_tornado_df)
# Out:
#                             Model      RMSE  R² Score
# 0        Linear Regression (Hail)  8.668422 -0.796127
# 1  Random Forest Regressor (Hail)  6.646847 -0.056059

# %%
# Plot learning curves using MSE for tornado models
for name, model in tornado_models.items():
    train_sizes, train_scores, test_scores = learning_curve(
        estimator=model,
        X=X_train_scaled_flood,  # Tornado features
        y=y_train_flood,         # Tornado target
        train_sizes=np.linspace(0.1, 1.0, 10),
        cv=5,
        scoring='neg_mean_squared_error',
        n_jobs=-1
    )

    # Convert negative MSE to positive values
    train_mse_mean = -np.mean(train_scores, axis=1)
    test_mse_mean = -np.mean(test_scores, axis=1)

    # Plot
    plt.figure(figsize=(8, 6))
    plt.plot(train_sizes, train_mse_mean, label="Training MSE", marker='o')
    plt.plot(train_sizes, test_mse_mean, label="Validation MSE", marker='s')
    plt.title(f"Learning Curve: {name}")
    plt.xlabel("Training Set Size")
    plt.ylabel("Mean Squared Error")
    plt.legend(loc="best")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
tornado_models = {
    "Random Forest Regressor (Hails)": RandomForestRegressor(
        n_estimators=100, random_state=42
    ),
}

pred_dict = {}          # store predictions for later plotting
results_tornado = []    # store metrics for a quick table

for name, model in tornado_models.items():
    model.fit(X_train_scaled_flood, y_train_flood)
    preds = model.predict(X_test_scaled_flood)

    # Save for plotting
    pred_dict[name] = preds

    # Metrics
    rmse = np.sqrt(mean_squared_error(y_test_flood, preds))
    r2   = r2_score(y_test_flood, preds)

    results_tornado.append({"Model": name, "RMSE": rmse, "R² Score": r2})

# Neat metrics table in case you need it
results_tornado_df = pd.DataFrame(results_tornado)
print(results_tornado_df.to_string(index=False))


plt.figure(figsize=(10, 5))

# Ground‑truth
plt.plot(
    y_test_flood.values,
    label="True value",
    linewidth=2,
)

# Each model’s curve
for name, preds in pred_dict.items():
    plt.plot(
        preds,
        linewidth=1,
        alpha=0.8,
        label=name,        # legend entry
    )

plt.ylim(-10, 30)                 # keep your original y‑axis limits
plt.xlabel("Sample index")
plt.ylabel("Damage cost")
plt.title("True vs. Predicted values on test set")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#                           Model     RMSE  R² Score
# Random Forest Regressor (Hails) 6.646847 -0.056059

# %%
# SAve the model
rf_model = tornado_models["Random Forest Regressor (Flash Floods)"]

#joblib.dump(rf_model, "models/random_forest_tornado_hail.pkl")   # any filename you like
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 # SAve the model
# ----> 2 rf_model = tornado_models["Random Forest Regressor (Flash Floods)"]
#       4 #joblib.dump(rf_model, "models/random_forest_tornado_hail.pkl")   # any filename you like
#
# KeyError: 'Random Forest Regressor (Flash Floods)'

# %% [markdown]
# # Neural Network Regression

# %%
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_train_t = torch.tensor(X_train_scaled_flood.values, dtype=torch.float32)
X_test_t  = torch.tensor(X_test_scaled_flood.values,  dtype=torch.float32)

# scale the target (z‑score)
#y_scaler     = StandardScaler()
##y_train_z    = y_scaler.fit_transform(y_train.reshape(-1, 1)).ravel()
#y_test_z     = y_scaler.transform(y_test.reshape(-1, 1)).ravel()

y_train_t = torch.tensor(y_train_flood.values, dtype=torch.float32).unsqueeze(1)
y_test_t  = torch.tensor(y_test_flood.values, dtype=torch.float32).unsqueeze(1)

ds_full = TensorDataset(X_train_t, y_train_t)

# Validation split  (80 % train / 20 % val)
val_frac = 0.2
val_size = int(len(ds_full) * val_frac)
train_size = len(ds_full) - val_size
ds_train, ds_val = random_split(ds_full, [train_size, val_size],
                                generator=torch.Generator().manual_seed(42))

loader_train = DataLoader(ds_train, batch_size=16, shuffle=True)
loader_val   = DataLoader(ds_val,   batch_size=64, shuffle=False)

# %%
class MLPRegressor(nn.Module):
    def __init__(self, in_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)        # linear output (z‑score of y)
        )

    def forward(self, x):
        return self.net(x)

model = MLPRegressor(X_train_t.shape[1]).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)


best_val = np.inf
patience, patience_cnt = 20, 0
n_epochs = 500
step = 0
training_loss = []
val_loss_list = []
for epoch in range(1, n_epochs + 1):
    # --- training step ---
    model.train()
    for xb, yb in loader_train:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        step +=1
        print(f"Epoch: {epoch}, Training Loss step:{step}-MSE:{loss}")
        training_loss.append(loss)

    # --- validation ---
    model.eval()
    with torch.no_grad():
        val_losses = []
        for xb, yb in loader_val:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            val_losses.append(criterion(pred, yb).item())
        val_loss = np.mean(val_losses)
        val_loss_list.append(val_loss)
        

    # early‑stopping logic
    # if val_loss < best_val - 0.0001:
    #     best_val = val_loss
    #     best_state = model.state_dict()
    #     patience_cnt = 0
    # else:
    #     patience_cnt += 1
    #     if patience_cnt >= patience:
    #         print(f"Early stopping at epoch {epoch}")
    #         break
# Out:
# Epoch: 1, Training Loss step:1-MSE:122.84001159667969
# Epoch: 1, Training Loss step:2-MSE:109.02497863769531
# Epoch: 1, Training Loss step:3-MSE:43.138526916503906
# Epoch: 1, Training Loss step:4-MSE:152.09983825683594
# Epoch: 1, Training Loss step:5-MSE:114.0405044555664
# Epoch: 1, Training Loss step:6-MSE:117.1335678100586
# Epoch: 1, Training Loss step:7-MSE:80.64572143554688
# Epoch: 2, Training Loss step:8-MSE:119.42391204833984
# Epoch: 2, Training Loss step:9-MSE:77.15353393554688
# Epoch: 2, Training Loss step:10-MSE:159.32867431640625
# Epoch: 2, Training Loss step:11-MSE:86.94934844970703
# Epoch: 2, Training Loss step:12-MSE:104.22735595703125
# Epoch: 2, Training Loss step:13-MSE:93.92305755615234
# Epoch: 2, Training Loss step:14-MSE:73.23209381103516
# Epoch: 3, Training Loss step:15-MSE:112.37142944335938
# Epoch: 3, Training Loss step:16-MSE:89.89241790771484
# Epoch: 3, Training Loss step:17-MSE:97.46321105957031
# Epoch: 3, Training Loss step:18-MSE:107.21189880371094
# Epoch: 3, Training Loss step:19-MSE:92.06761169433594
# Epoch: 3, Training Loss step:20-MSE:90.05535125732422
# Epoch: 3, Training Loss step:21-MSE:109.1772232055664
# Epoch: 4, Training Loss step:22-MSE:87.42618560791016
# Epoch: 4, Training Loss step:23-MSE:75.81505584716797
# Epoch: 4, Training Loss step:24-MSE:71.42701721191406
# Epoch: 4, Training Loss step:25-MSE:99.7137451171875
# Epoch: 4, Training Loss step:26-MSE:99.20933532714844
# Epoch: 4, Training Loss step:27-MSE:74.02702331542969
# Epoch: 4, Training Loss step:28-MSE:154.06024169921875
# Epoch: 5, Training Loss step:29-MSE:115.31324005126953
# Epoch: 5, Training Loss step:30-MSE:56.88191223144531
# Epoch: 5, Training Loss step:31-MSE:100.24565124511719
# Epoch: 5, Training Loss step:32-MSE:51.37480926513672
# Epoch: 5, Training Loss step:33-MSE:73.18937683105469
# Epoch: 5, Training Loss step:34-MSE:75.64579010009766
# Epoch: 5, Training Loss step:35-MSE:53.21930694580078
# Epoch: 6, Training Loss step:36-MSE:87.38124084472656
# Epoch: 6, Training Loss step:37-MSE:57.32368469238281
# Epoch: 6, Training Loss step:38-MSE:51.65582275390625
# Epoch: 6, Training Loss step:39-MSE:54.22075653076172
# Epoch: 6, Training Loss step:40-MSE:40.25487518310547
# Epoch: 6, Training Loss step:41-MSE:60.00701904296875
# Epoch: 6, Training Loss step:42-MSE:87.64685821533203
# Epoch: 7, Training Loss step:43-MSE:33.857887268066406
# Epoch: 7, Training Loss step:44-MSE:37.993568420410156
# Epoch: 7, Training Loss step:45-MSE:47.84273910522461
# Epoch: 7, Training Loss step:46-MSE:50.049461364746094
# Epoch: 7, Training Loss step:47-MSE:52.58323669433594
# Epoch: 7, Training Loss step:48-MSE:55.47630310058594
# Epoch: 7, Training Loss step:49-MSE:40.80756759643555
# Epoch: 8, Training Loss step:50-MSE:53.46404266357422
# Epoch: 8, Training Loss step:51-MSE:32.96780776977539
# Epoch: 8, Training Loss step:52-MSE:43.29779052734375
# Epoch: 8, Training Loss step:53-MSE:35.5943717956543
# Epoch: 8, Training Loss step:54-MSE:41.91413116455078
# Epoch: 8, Training Loss step:55-MSE:54.242225646972656
# Epoch: 8, Training Loss step:56-MSE:52.886512756347656
# Epoch: 9, Training Loss step:57-MSE:32.79328155517578
# Epoch: 9, Training Loss step:58-MSE:28.053852081298828
# Epoch: 9, Training Loss step:59-MSE:23.895658493041992
# Epoch: 9, Training Loss step:60-MSE:61.66965103149414
# Epoch: 9, Training Loss step:61-MSE:67.92703247070312
# Epoch: 9, Training Loss step:62-MSE:29.387893676757812
# Epoch: 9, Training Loss step:63-MSE:38.93648147583008
# Epoch: 10, Training Loss step:64-MSE:28.681058883666992
# Epoch: 10, Training Loss step:65-MSE:43.35224151611328
# Epoch: 10, Training Loss step:66-MSE:37.62096405029297
# Epoch: 10, Training Loss step:67-MSE:44.696231842041016
# Epoch: 10, Training Loss step:68-MSE:44.58899688720703
# Epoch: 10, Training Loss step:69-MSE:25.0842342376709
# Epoch: 10, Training Loss step:70-MSE:31.819320678710938
# Epoch: 11, Training Loss step:71-MSE:32.66993713378906
# Epoch: 11, Training Loss step:72-MSE:35.65707015991211
# Epoch: 11, Training Loss step:73-MSE:32.33928298950195
# Epoch: 11, Training Loss step:74-MSE:29.711700439453125
# Epoch: 11, Training Loss step:75-MSE:36.997589111328125
# Epoch: 11, Training Loss step:76-MSE:52.208099365234375
# Epoch: 11, Training Loss step:77-MSE:9.033217430114746
# Epoch: 12, Training Loss step:78-MSE:33.652618408203125
# Epoch: 12, Training Loss step:79-MSE:16.2120361328125
# Epoch: 12, Training Loss step:80-MSE:44.74287414550781
# Epoch: 12, Training Loss step:81-MSE:42.68376159667969
# Epoch: 12, Training Loss step:82-MSE:35.48687744140625
# Epoch: 12, Training Loss step:83-MSE:16.771343231201172
# Epoch: 12, Training Loss step:84-MSE:68.68351745605469
# Epoch: 13, Training Loss step:85-MSE:14.94217300415039
# Epoch: 13, Training Loss step:86-MSE:33.88723373413086
# Epoch: 13, Training Loss step:87-MSE:27.292224884033203
# Epoch: 13, Training Loss step:88-MSE:28.32708740234375
# Epoch: 13, Training Loss step:89-MSE:48.230491638183594
# Epoch: 13, Training Loss step:90-MSE:30.024917602539062
# Epoch: 13, Training Loss step:91-MSE:35.344661712646484
# Epoch: 14, Training Loss step:92-MSE:28.96643829345703
# Epoch: 14, Training Loss step:93-MSE:19.368919372558594
# Epoch: 14, Training Loss step:94-MSE:20.329524993896484
# Epoch: 14, Training Loss step:95-MSE:33.50848388671875
# Epoch: 14, Training Loss step:96-MSE:38.3070068359375
# Epoch: 14, Training Loss step:97-MSE:41.05326843261719
# Epoch: 14, Training Loss step:98-MSE:29.13534164428711
# Epoch: 15, Training Loss step:99-MSE:53.47036361694336
# Epoch: 15, Training Loss step:100-MSE:17.227731704711914
# Epoch: 15, Training Loss step:101-MSE:19.491844177246094
# Epoch: 15, Training Loss step:102-MSE:26.6649169921875
# Epoch: 15, Training Loss step:103-MSE:40.1455192565918
# Epoch: 15, Training Loss step:104-MSE:26.6430721282959
# Epoch: 15, Training Loss step:105-MSE:23.46137046813965
# Epoch: 16, Training Loss step:106-MSE:20.579477310180664
# Epoch: 16, Training Loss step:107-MSE:30.531375885009766
# Epoch: 16, Training Loss step:108-MSE:27.48140525817871
# Epoch: 16, Training Loss step:109-MSE:28.701919555664062
# Epoch: 16, Training Loss step:110-MSE:34.83415222167969
# Epoch: 16, Training Loss step:111-MSE:36.20116424560547
# Epoch: 16, Training Loss step:112-MSE:9.66407585144043
# Epoch: 17, Training Loss step:113-MSE:10.769655227661133
# Epoch: 17, Training Loss step:114-MSE:48.489662170410156
# Epoch: 17, Training Loss step:115-MSE:16.29690170288086
# Epoch: 17, Training Loss step:116-MSE:33.07202911376953
# Epoch: 17, Training Loss step:117-MSE:26.20792007446289
# Epoch: 17, Training Loss step:118-MSE:29.599609375
# Epoch: 17, Training Loss step:119-MSE:34.79066467285156
# Epoch: 18, Training Loss step:120-MSE:51.49238586425781
# Epoch: 18, Training Loss step:121-MSE:20.469139099121094
# Epoch: 18, Training Loss step:122-MSE:24.943565368652344
# Epoch: 18, Training Loss step:123-MSE:15.753643035888672
# Epoch: 18, Training Loss step:124-MSE:32.29588317871094
# Epoch: 18, Training Loss step:125-MSE:20.080080032348633
# Epoch: 18, Training Loss step:126-MSE:36.345985412597656
# Epoch: 19, Training Loss step:127-MSE:31.40752601623535
# Epoch: 19, Training Loss step:128-MSE:32.84070587158203
# Epoch: 19, Training Loss step:129-MSE:26.31283950805664
# Epoch: 19, Training Loss step:130-MSE:20.382827758789062
# Epoch: 19, Training Loss step:131-MSE:35.06025314331055
# Epoch: 19, Training Loss step:132-MSE:22.949832916259766
# Epoch: 19, Training Loss step:133-MSE:14.98890495300293
# Epoch: 20, Training Loss step:134-MSE:23.317602157592773
# Epoch: 20, Training Loss step:135-MSE:25.506175994873047
# Epoch: 20, Training Loss step:136-MSE:31.26658821105957
# Epoch: 20, Training Loss step:137-MSE:14.991311073303223
# Epoch: 20, Training Loss step:138-MSE:37.950592041015625
# Epoch: 20, Training Loss step:139-MSE:19.951887130737305
# Epoch: 20, Training Loss step:140-MSE:37.76397705078125
# Epoch: 21, Training Loss step:141-MSE:19.584056854248047
# Epoch: 21, Training Loss step:142-MSE:19.501794815063477
# Epoch: 21, Training Loss step:143-MSE:28.006694793701172
# Epoch: 21, Training Loss step:144-MSE:17.457324981689453
# Epoch: 21, Training Loss step:145-MSE:23.960744857788086
# Epoch: 21, Training Loss step:146-MSE:45.83123016357422
# Epoch: 21, Training Loss step:147-MSE:33.448123931884766
# Epoch: 22, Training Loss step:148-MSE:24.142559051513672
# Epoch: 22, Training Loss step:149-MSE:8.724843978881836
# Epoch: 22, Training Loss step:150-MSE:46.92779541015625
# Epoch: 22, Training Loss step:151-MSE:13.621021270751953
# Epoch: 22, Training Loss step:152-MSE:13.449742317199707
# Epoch: 22, Training Loss step:153-MSE:49.49091339111328
# Epoch: 22, Training Loss step:154-MSE:38.88082504272461
# Epoch: 23, Training Loss step:155-MSE:40.858455657958984
# Epoch: 23, Training Loss step:156-MSE:29.121204376220703
# Epoch: 23, Training Loss step:157-MSE:25.161663055419922
# Epoch: 23, Training Loss step:158-MSE:21.919448852539062
# Epoch: 23, Training Loss step:159-MSE:13.340167999267578
# Epoch: 23, Training Loss step:160-MSE:14.28317642211914
# Epoch: 23, Training Loss step:161-MSE:21.615266799926758
# Epoch: 24, Training Loss step:162-MSE:35.06841278076172
# Epoch: 24, Training Loss step:163-MSE:15.717941284179688
# Epoch: 24, Training Loss step:164-MSE:16.76951789855957
# Epoch: 24, Training Loss step:165-MSE:46.03427505493164
# Epoch: 24, Training Loss step:166-MSE:21.711650848388672
# Epoch: 24, Training Loss step:167-MSE:17.54450225830078
# Epoch: 24, Training Loss step:168-MSE:27.097095489501953
# Epoch: 25, Training Loss step:169-MSE:17.668869018554688
# Epoch: 25, Training Loss step:170-MSE:20.85993194580078
# Epoch: 25, Training Loss step:171-MSE:27.555831909179688
# Epoch: 25, Training Loss step:172-MSE:21.24582862854004
# Epoch: 25, Training Loss step:173-MSE:35.962425231933594
# Epoch: 25, Training Loss step:174-MSE:19.640613555908203
# Epoch: 25, Training Loss step:175-MSE:23.77332305908203
# Epoch: 26, Training Loss step:176-MSE:6.404140472412109
# Epoch: 26, Training Loss step:177-MSE:17.774372100830078
# Epoch: 26, Training Loss step:178-MSE:35.259681701660156
# Epoch: 26, Training Loss step:179-MSE:24.19965362548828
# Epoch: 26, Training Loss step:180-MSE:35.72122573852539
# Epoch: 26, Training Loss step:181-MSE:21.107868194580078
# Epoch: 26, Training Loss step:182-MSE:19.20993995666504
# Epoch: 27, Training Loss step:183-MSE:20.8900146484375
# Epoch: 27, Training Loss step:184-MSE:44.20932388305664
# Epoch: 27, Training Loss step:185-MSE:27.815044403076172
# Epoch: 27, Training Loss step:186-MSE:20.59433364868164
# Epoch: 27, Training Loss step:187-MSE:25.414365768432617
# Epoch: 27, Training Loss step:188-MSE:13.777938842773438
# Epoch: 27, Training Loss step:189-MSE:21.133432388305664
# Epoch: 28, Training Loss step:190-MSE:21.21800994873047
# Epoch: 28, Training Loss step:191-MSE:24.224075317382812
# Epoch: 28, Training Loss step:192-MSE:34.0068359375
# Epoch: 28, Training Loss step:193-MSE:9.268755912780762
# Epoch: 28, Training Loss step:194-MSE:21.225313186645508
# Epoch: 28, Training Loss step:195-MSE:25.56454086303711
# Epoch: 28, Training Loss step:196-MSE:30.704544067382812
# Epoch: 29, Training Loss step:197-MSE:19.204601287841797
# Epoch: 29, Training Loss step:198-MSE:22.56148910522461
# Epoch: 29, Training Loss step:199-MSE:22.57801055908203
# Epoch: 29, Training Loss step:200-MSE:18.778684616088867
# Epoch: 29, Training Loss step:201-MSE:21.403114318847656
# Epoch: 29, Training Loss step:202-MSE:30.417163848876953
# Epoch: 29, Training Loss step:203-MSE:43.81761932373047
# Epoch: 30, Training Loss step:204-MSE:37.2337646484375
# Epoch: 30, Training Loss step:205-MSE:44.077510833740234
# Epoch: 30, Training Loss step:206-MSE:13.294198989868164
# Epoch: 30, Training Loss step:207-MSE:18.657224655151367
# Epoch: 30, Training Loss step:208-MSE:19.791608810424805
# Epoch: 30, Training Loss step:209-MSE:9.85234260559082
# Epoch: 30, Training Loss step:210-MSE:16.10586166381836
# Epoch: 31, Training Loss step:211-MSE:12.750083923339844
# Epoch: 31, Training Loss step:212-MSE:23.62613868713379
# Epoch: 31, Training Loss step:213-MSE:21.132461547851562
# Epoch: 31, Training Loss step:214-MSE:38.39039993286133
# Epoch: 31, Training Loss step:215-MSE:18.65195083618164
# Epoch: 31, Training Loss step:216-MSE:13.62424087524414
# Epoch: 31, Training Loss step:217-MSE:46.991050720214844
# Epoch: 32, Training Loss step:218-MSE:13.08808708190918
# Epoch: 32, Training Loss step:219-MSE:29.524198532104492
# Epoch: 32, Training Loss step:220-MSE:22.529937744140625
# Epoch: 32, Training Loss step:221-MSE:29.787216186523438
# Epoch: 32, Training Loss step:222-MSE:20.085437774658203
# Epoch: 32, Training Loss step:223-MSE:19.31700325012207
# Epoch: 32, Training Loss step:224-MSE:12.726090431213379
# Epoch: 33, Training Loss step:225-MSE:27.517967224121094
# Epoch: 33, Training Loss step:226-MSE:12.972091674804688
# Epoch: 33, Training Loss step:227-MSE:27.698055267333984
# Epoch: 33, Training Loss step:228-MSE:16.583118438720703
# Epoch: 33, Training Loss step:229-MSE:20.454700469970703
# Epoch: 33, Training Loss step:230-MSE:34.30162811279297
# Epoch: 33, Training Loss step:231-MSE:11.224994659423828
# Epoch: 34, Training Loss step:232-MSE:38.399314880371094
# Epoch: 34, Training Loss step:233-MSE:27.03925323486328
# Epoch: 34, Training Loss step:234-MSE:16.67272186279297
# Epoch: 34, Training Loss step:235-MSE:16.882362365722656
# Epoch: 34, Training Loss step:236-MSE:15.203519821166992
# Epoch: 34, Training Loss step:237-MSE:19.241817474365234
# Epoch: 34, Training Loss step:238-MSE:1.7486919164657593
# Epoch: 35, Training Loss step:239-MSE:10.43917465209961
# Epoch: 35, Training Loss step:240-MSE:13.895851135253906
# Epoch: 35, Training Loss step:241-MSE:28.766712188720703
# Epoch: 35, Training Loss step:242-MSE:30.207862854003906
# Epoch: 35, Training Loss step:243-MSE:26.580142974853516
# Epoch: 35, Training Loss step:244-MSE:27.866931915283203
# Epoch: 35, Training Loss step:245-MSE:9.235410690307617
# Epoch: 36, Training Loss step:246-MSE:17.677701950073242
# Epoch: 36, Training Loss step:247-MSE:8.769082069396973
# Epoch: 36, Training Loss step:248-MSE:24.02031707763672
# Epoch: 36, Training Loss step:249-MSE:34.882057189941406
# Epoch: 36, Training Loss step:250-MSE:19.909303665161133
# Epoch: 36, Training Loss step:251-MSE:8.350279808044434
# Epoch: 36, Training Loss step:252-MSE:26.141101837158203
# Epoch: 37, Training Loss step:253-MSE:33.224456787109375
# Epoch: 37, Training Loss step:254-MSE:10.472554206848145
# Epoch: 37, Training Loss step:255-MSE:10.849241256713867
# Epoch: 37, Training Loss step:256-MSE:15.129467010498047
# Epoch: 37, Training Loss step:257-MSE:26.65035629272461
# Epoch: 37, Training Loss step:258-MSE:29.473491668701172
# Epoch: 37, Training Loss step:259-MSE:15.892728805541992
# Epoch: 38, Training Loss step:260-MSE:18.290311813354492
# Epoch: 38, Training Loss step:261-MSE:14.521821975708008
# Epoch: 38, Training Loss step:262-MSE:29.64556312561035
# Epoch: 38, Training Loss step:263-MSE:24.56163787841797
# Epoch: 38, Training Loss step:264-MSE:13.52880859375
# Epoch: 38, Training Loss step:265-MSE:22.700904846191406
# Epoch: 38, Training Loss step:266-MSE:10.561360359191895
# Epoch: 39, Training Loss step:267-MSE:37.477516174316406
# Epoch: 39, Training Loss step:268-MSE:19.104923248291016
# Epoch: 39, Training Loss step:269-MSE:12.806023597717285
# Epoch: 39, Training Loss step:270-MSE:10.488142967224121
# Epoch: 39, Training Loss step:271-MSE:12.88358211517334
# Epoch: 39, Training Loss step:272-MSE:34.51350784301758
# Epoch: 39, Training Loss step:273-MSE:11.789128303527832
# Epoch: 40, Training Loss step:274-MSE:26.085784912109375
# Epoch: 40, Training Loss step:275-MSE:17.59247398376465
# Epoch: 40, Training Loss step:276-MSE:20.897483825683594
# Epoch: 40, Training Loss step:277-MSE:14.210406303405762
# Epoch: 40, Training Loss step:278-MSE:31.38804817199707
# Epoch: 40, Training Loss step:279-MSE:12.382059097290039
# Epoch: 40, Training Loss step:280-MSE:17.407148361206055
# Epoch: 41, Training Loss step:281-MSE:18.04007339477539
# Epoch: 41, Training Loss step:282-MSE:24.323627471923828
# Epoch: 41, Training Loss step:283-MSE:10.71259880065918
# Epoch: 41, Training Loss step:284-MSE:14.024602890014648
# Epoch: 41, Training Loss step:285-MSE:19.962295532226562
# Epoch: 41, Training Loss step:286-MSE:28.33831214904785
# Epoch: 41, Training Loss step:287-MSE:18.379138946533203
# Epoch: 42, Training Loss step:288-MSE:12.256734848022461
# Epoch: 42, Training Loss step:289-MSE:16.45541763305664
# Epoch: 42, Training Loss step:290-MSE:25.10498046875
# Epoch: 42, Training Loss step:291-MSE:16.45083999633789
# Epoch: 42, Training Loss step:292-MSE:19.499507904052734
# Epoch: 42, Training Loss step:293-MSE:20.074405670166016
# Epoch: 42, Training Loss step:294-MSE:28.49860382080078
# Epoch: 43, Training Loss step:295-MSE:22.883758544921875
# Epoch: 43, Training Loss step:296-MSE:15.051612854003906
# Epoch: 43, Training Loss step:297-MSE:18.652009963989258
# Epoch: 43, Training Loss step:298-MSE:10.605466842651367
# Epoch: 43, Training Loss step:299-MSE:33.48934555053711
# Epoch: 43, Training Loss step:300-MSE:12.952247619628906
# Epoch: 43, Training Loss step:301-MSE:8.979403495788574
# Epoch: 44, Training Loss step:302-MSE:12.646366119384766
# Epoch: 44, Training Loss step:303-MSE:18.816452026367188
# Epoch: 44, Training Loss step:304-MSE:23.69513511657715
# Epoch: 44, Training Loss step:305-MSE:20.037212371826172
# Epoch: 44, Training Loss step:306-MSE:12.64207649230957
# Epoch: 44, Training Loss step:307-MSE:30.945789337158203
# Epoch: 44, Training Loss step:308-MSE:10.743037223815918
# Epoch: 45, Training Loss step:309-MSE:4.8745927810668945
# Epoch: 45, Training Loss step:310-MSE:30.37897300720215
# Epoch: 45, Training Loss step:311-MSE:19.40509796142578
# Epoch: 45, Training Loss step:312-MSE:15.51342487335205
# Epoch: 45, Training Loss step:313-MSE:18.20630645751953
# Epoch: 45, Training Loss step:314-MSE:15.374464988708496
# Epoch: 45, Training Loss step:315-MSE:13.662809371948242
# Epoch: 46, Training Loss step:316-MSE:25.28455352783203
# Epoch: 46, Training Loss step:317-MSE:20.653186798095703
# Epoch: 46, Training Loss step:318-MSE:24.016836166381836
# Epoch: 46, Training Loss step:319-MSE:15.378534317016602
# Epoch: 46, Training Loss step:320-MSE:15.56063175201416
# Epoch: 46, Training Loss step:321-MSE:9.514554023742676
# Epoch: 46, Training Loss step:322-MSE:8.686249732971191
# Epoch: 47, Training Loss step:323-MSE:13.059123992919922
# Epoch: 47, Training Loss step:324-MSE:13.967582702636719
# Epoch: 47, Training Loss step:325-MSE:30.464820861816406
# Epoch: 47, Training Loss step:326-MSE:13.96618366241455
# Epoch: 47, Training Loss step:327-MSE:10.112821578979492
# Epoch: 47, Training Loss step:328-MSE:19.867050170898438
# Epoch: 47, Training Loss step:329-MSE:5.917087078094482
# Epoch: 48, Training Loss step:330-MSE:20.961578369140625
# Epoch: 48, Training Loss step:331-MSE:8.366500854492188
# Epoch: 48, Training Loss step:332-MSE:8.792237281799316
# Epoch: 48, Training Loss step:333-MSE:14.058514595031738
# Epoch: 48, Training Loss step:334-MSE:36.340065002441406
# Epoch: 48, Training Loss step:335-MSE:15.00094985961914
# Epoch: 48, Training Loss step:336-MSE:5.225591659545898
# Epoch: 49, Training Loss step:337-MSE:10.320086479187012
# Epoch: 49, Training Loss step:338-MSE:24.680988311767578
# Epoch: 49, Training Loss step:339-MSE:21.8873348236084
# Epoch: 49, Training Loss step:340-MSE:21.777141571044922
# Epoch: 49, Training Loss step:341-MSE:11.598783493041992
# Epoch: 49, Training Loss step:342-MSE:9.773701667785645
# Epoch: 49, Training Loss step:343-MSE:14.440723419189453
# Epoch: 50, Training Loss step:344-MSE:9.661173820495605
# Epoch: 50, Training Loss step:345-MSE:6.489734649658203
# Epoch: 50, Training Loss step:346-MSE:21.334739685058594
# Epoch: 50, Training Loss step:347-MSE:22.059181213378906
# Epoch: 50, Training Loss step:348-MSE:13.417917251586914
# Epoch: 50, Training Loss step:349-MSE:9.000650405883789
# Epoch: 50, Training Loss step:350-MSE:42.6535530090332
# Epoch: 51, Training Loss step:351-MSE:13.074707984924316
# Epoch: 51, Training Loss step:352-MSE:19.97482681274414
# Epoch: 51, Training Loss step:353-MSE:11.871220588684082
# Epoch: 51, Training Loss step:354-MSE:22.3833065032959
# Epoch: 51, Training Loss step:355-MSE:14.403581619262695
# Epoch: 51, Training Loss step:356-MSE:18.16636085510254
# Epoch: 51, Training Loss step:357-MSE:19.275583267211914
# Epoch: 52, Training Loss step:358-MSE:18.38498306274414
# Epoch: 52, Training Loss step:359-MSE:11.809123992919922
# Epoch: 52, Training Loss step:360-MSE:9.868602752685547
# Epoch: 52, Training Loss step:361-MSE:14.886444091796875
# Epoch: 52, Training Loss step:362-MSE:16.596054077148438
# Epoch: 52, Training Loss step:363-MSE:11.557836532592773
# Epoch: 52, Training Loss step:364-MSE:19.81615447998047
# Epoch: 53, Training Loss step:365-MSE:21.713239669799805
# Epoch: 53, Training Loss step:366-MSE:8.594694137573242
# Epoch: 53, Training Loss step:367-MSE:22.926773071289062
# Epoch: 53, Training Loss step:368-MSE:8.680644989013672
# Epoch: 53, Training Loss step:369-MSE:18.98592185974121
# Epoch: 53, Training Loss step:370-MSE:7.978695392608643
# Epoch: 53, Training Loss step:371-MSE:16.290512084960938
# Epoch: 54, Training Loss step:372-MSE:15.738609313964844
# Epoch: 54, Training Loss step:373-MSE:10.834205627441406
# Epoch: 54, Training Loss step:374-MSE:20.27934455871582
# Epoch: 54, Training Loss step:375-MSE:19.828977584838867
# Epoch: 54, Training Loss step:376-MSE:7.319674491882324
# Epoch: 54, Training Loss step:377-MSE:12.417522430419922
# Epoch: 54, Training Loss step:378-MSE:10.304550170898438
# Epoch: 55, Training Loss step:379-MSE:11.861611366271973
# Epoch: 55, Training Loss step:380-MSE:15.59405517578125
# Epoch: 55, Training Loss step:381-MSE:9.331113815307617
# Epoch: 55, Training Loss step:382-MSE:23.68865966796875
# Epoch: 55, Training Loss step:383-MSE:7.202365875244141
# Epoch: 55, Training Loss step:384-MSE:13.672481536865234
# Epoch: 55, Training Loss step:385-MSE:15.036273002624512
# Epoch: 56, Training Loss step:386-MSE:17.44165802001953
# Epoch: 56, Training Loss step:387-MSE:4.468145847320557
# Epoch: 56, Training Loss step:388-MSE:15.94400405883789
# Epoch: 56, Training Loss step:389-MSE:13.714482307434082
# Epoch: 56, Training Loss step:390-MSE:28.53228759765625
# Epoch: 56, Training Loss step:391-MSE:11.585792541503906
# Epoch: 56, Training Loss step:392-MSE:8.36834716796875
# Epoch: 57, Training Loss step:393-MSE:29.625137329101562
# Epoch: 57, Training Loss step:394-MSE:5.800947189331055
# Epoch: 57, Training Loss step:395-MSE:9.313315391540527
# Epoch: 57, Training Loss step:396-MSE:27.25513458251953
# Epoch: 57, Training Loss step:397-MSE:13.797285079956055
# Epoch: 57, Training Loss step:398-MSE:5.952004432678223
# Epoch: 57, Training Loss step:399-MSE:4.634653568267822
# Epoch: 58, Training Loss step:400-MSE:10.228863716125488
# Epoch: 58, Training Loss step:401-MSE:20.156936645507812
# Epoch: 58, Training Loss step:402-MSE:3.317293167114258
# Epoch: 58, Training Loss step:403-MSE:18.1539363861084
# Epoch: 58, Training Loss step:404-MSE:8.88791275024414
# Epoch: 58, Training Loss step:405-MSE:19.79735565185547
# Epoch: 58, Training Loss step:406-MSE:7.996978759765625
# Epoch: 59, Training Loss step:407-MSE:14.251338958740234
# Epoch: 59, Training Loss step:408-MSE:10.536911010742188
# Epoch: 59, Training Loss step:409-MSE:26.9293155670166
# Epoch: 59, Training Loss step:410-MSE:6.013915538787842
# Epoch: 59, Training Loss step:411-MSE:7.514285564422607
# Epoch: 59, Training Loss step:412-MSE:16.424510955810547
# Epoch: 59, Training Loss step:413-MSE:8.336164474487305
# Epoch: 60, Training Loss step:414-MSE:36.012874603271484
# Epoch: 60, Training Loss step:415-MSE:7.513618469238281
# Epoch: 60, Training Loss step:416-MSE:6.031881332397461
# Epoch: 60, Training Loss step:417-MSE:12.797842979431152
# Epoch: 60, Training Loss step:418-MSE:6.476802825927734
# Epoch: 60, Training Loss step:419-MSE:11.614538192749023
# Epoch: 60, Training Loss step:420-MSE:8.186391830444336
# Epoch: 61, Training Loss step:421-MSE:18.321208953857422
# Epoch: 61, Training Loss step:422-MSE:8.488823890686035
# Epoch: 61, Training Loss step:423-MSE:10.84858512878418
# Epoch: 61, Training Loss step:424-MSE:4.866554260253906
# Epoch: 61, Training Loss step:425-MSE:23.73579216003418
# Epoch: 61, Training Loss step:426-MSE:28.359689712524414
# Epoch: 61, Training Loss step:427-MSE:4.50600004196167
# Epoch: 62, Training Loss step:428-MSE:20.8823184967041
# Epoch: 62, Training Loss step:429-MSE:12.169734954833984
# Epoch: 62, Training Loss step:430-MSE:7.381651878356934
# Epoch: 62, Training Loss step:431-MSE:6.489814758300781
# Epoch: 62, Training Loss step:432-MSE:18.555330276489258
# Epoch: 62, Training Loss step:433-MSE:22.971614837646484
# Epoch: 62, Training Loss step:434-MSE:3.9871206283569336
# Epoch: 63, Training Loss step:435-MSE:8.134332656860352
# Epoch: 63, Training Loss step:436-MSE:18.029909133911133
# Epoch: 63, Training Loss step:437-MSE:12.947498321533203
# Epoch: 63, Training Loss step:438-MSE:13.607169151306152
# Epoch: 63, Training Loss step:439-MSE:8.835163116455078
# Epoch: 63, Training Loss step:440-MSE:16.907405853271484
# Epoch: 63, Training Loss step:441-MSE:5.677461624145508
# Epoch: 64, Training Loss step:442-MSE:20.335437774658203
# Epoch: 64, Training Loss step:443-MSE:4.870318412780762
# Epoch: 64, Training Loss step:444-MSE:16.125167846679688
# Epoch: 64, Training Loss step:445-MSE:7.70263671875
# Epoch: 64, Training Loss step:446-MSE:14.4840087890625
# Epoch: 64, Training Loss step:447-MSE:3.148144006729126
# Epoch: 64, Training Loss step:448-MSE:8.29311466217041
# Epoch: 65, Training Loss step:449-MSE:19.874032974243164
# Epoch: 65, Training Loss step:450-MSE:12.47536563873291
# Epoch: 65, Training Loss step:451-MSE:6.235962867736816
# Epoch: 65, Training Loss step:452-MSE:10.052964210510254
# Epoch: 65, Training Loss step:453-MSE:16.224468231201172
# Epoch: 65, Training Loss step:454-MSE:12.206717491149902
# Epoch: 65, Training Loss step:455-MSE:1.9108213186264038
# Epoch: 66, Training Loss step:456-MSE:10.799922943115234
# Epoch: 66, Training Loss step:457-MSE:10.856243133544922
# Epoch: 66, Training Loss step:458-MSE:17.106704711914062
# Epoch: 66, Training Loss step:459-MSE:9.119884490966797
# Epoch: 66, Training Loss step:460-MSE:5.771806240081787
# Epoch: 66, Training Loss step:461-MSE:16.301076889038086
# Epoch: 66, Training Loss step:462-MSE:5.362112045288086
# Epoch: 67, Training Loss step:463-MSE:4.949388027191162
# Epoch: 67, Training Loss step:464-MSE:21.16566276550293
# Epoch: 67, Training Loss step:465-MSE:4.099798679351807
# Epoch: 67, Training Loss step:466-MSE:8.397095680236816
# Epoch: 67, Training Loss step:467-MSE:23.026004791259766
# Epoch: 67, Training Loss step:468-MSE:10.886391639709473
# Epoch: 67, Training Loss step:469-MSE:21.561702728271484
# Epoch: 68, Training Loss step:470-MSE:12.583837509155273
# Epoch: 68, Training Loss step:471-MSE:20.25111961364746
# Epoch: 68, Training Loss step:472-MSE:17.07762336730957
# Epoch: 68, Training Loss step:473-MSE:7.39431095123291
# Epoch: 68, Training Loss step:474-MSE:8.805686950683594
# Epoch: 68, Training Loss step:475-MSE:7.275463104248047
# Epoch: 68, Training Loss step:476-MSE:7.7731757164001465
# Epoch: 69, Training Loss step:477-MSE:6.708957195281982
# Epoch: 69, Training Loss step:478-MSE:6.3236541748046875
# Epoch: 69, Training Loss step:479-MSE:20.47524642944336
# Epoch: 69, Training Loss step:480-MSE:9.927549362182617
# Epoch: 69, Training Loss step:481-MSE:20.08305549621582
# Epoch: 69, Training Loss step:482-MSE:8.125272750854492
# Epoch: 69, Training Loss step:483-MSE:7.927079677581787
# Epoch: 70, Training Loss step:484-MSE:15.124685287475586
# Epoch: 70, Training Loss step:485-MSE:14.129998207092285
# Epoch: 70, Training Loss step:486-MSE:8.553460121154785
# Epoch: 70, Training Loss step:487-MSE:10.250049591064453
# Epoch: 70, Training Loss step:488-MSE:17.242467880249023
# Epoch: 70, Training Loss step:489-MSE:10.725412368774414
# Epoch: 70, Training Loss step:490-MSE:6.340756893157959
# Epoch: 71, Training Loss step:491-MSE:8.416552543640137
# Epoch: 71, Training Loss step:492-MSE:5.288784027099609
# Epoch: 71, Training Loss step:493-MSE:3.7760393619537354
# Epoch: 71, Training Loss step:494-MSE:22.484329223632812
# Epoch: 71, Training Loss step:495-MSE:16.67327880859375
# Epoch: 71, Training Loss step:496-MSE:8.785943984985352
# Epoch: 71, Training Loss step:497-MSE:2.4242238998413086
# Epoch: 72, Training Loss step:498-MSE:13.119514465332031
# Epoch: 72, Training Loss step:499-MSE:10.413134574890137
# Epoch: 72, Training Loss step:500-MSE:6.372214317321777
# Epoch: 72, Training Loss step:501-MSE:6.302867412567139
# Epoch: 72, Training Loss step:502-MSE:15.059494018554688
# Epoch: 72, Training Loss step:503-MSE:17.919063568115234
# Epoch: 72, Training Loss step:504-MSE:8.259535789489746
# Epoch: 73, Training Loss step:505-MSE:16.288097381591797
# Epoch: 73, Training Loss step:506-MSE:6.051995277404785
# Epoch: 73, Training Loss step:507-MSE:10.533674240112305
# Epoch: 73, Training Loss step:508-MSE:19.255903244018555
# Epoch: 73, Training Loss step:509-MSE:7.271698951721191
# Epoch: 73, Training Loss step:510-MSE:9.068380355834961
# Epoch: 73, Training Loss step:511-MSE:9.138616561889648
# Epoch: 74, Training Loss step:512-MSE:16.88287925720215
# Epoch: 74, Training Loss step:513-MSE:5.825872898101807
# Epoch: 74, Training Loss step:514-MSE:7.181739807128906
# Epoch: 74, Training Loss step:515-MSE:6.247727394104004
# Epoch: 74, Training Loss step:516-MSE:14.932462692260742
# Epoch: 74, Training Loss step:517-MSE:16.695438385009766
# Epoch: 74, Training Loss step:518-MSE:5.626368999481201
# Epoch: 75, Training Loss step:519-MSE:9.83963394165039
# Epoch: 75, Training Loss step:520-MSE:7.780175685882568
# Epoch: 75, Training Loss step:521-MSE:6.883170127868652
# Epoch: 75, Training Loss step:522-MSE:8.782194137573242
# Epoch: 75, Training Loss step:523-MSE:5.76055908203125
# Epoch: 75, Training Loss step:524-MSE:18.67633819580078
# Epoch: 75, Training Loss step:525-MSE:11.004427909851074
# Epoch: 76, Training Loss step:526-MSE:20.731151580810547
# Epoch: 76, Training Loss step:527-MSE:17.499683380126953
# Epoch: 76, Training Loss step:528-MSE:5.412292957305908
# Epoch: 76, Training Loss step:529-MSE:7.877233505249023
# Epoch: 76, Training Loss step:530-MSE:8.096076011657715
# Epoch: 76, Training Loss step:531-MSE:9.200459480285645
# Epoch: 76, Training Loss step:532-MSE:3.1370022296905518
# Epoch: 77, Training Loss step:533-MSE:14.208230972290039
# Epoch: 77, Training Loss step:534-MSE:4.38762092590332
# Epoch: 77, Training Loss step:535-MSE:24.970354080200195
# Epoch: 77, Training Loss step:536-MSE:13.477294921875
# Epoch: 77, Training Loss step:537-MSE:5.70348596572876
# Epoch: 77, Training Loss step:538-MSE:7.150897979736328
# Epoch: 77, Training Loss step:539-MSE:10.512236595153809
# Epoch: 78, Training Loss step:540-MSE:7.804450511932373
# Epoch: 78, Training Loss step:541-MSE:7.123549461364746
# Epoch: 78, Training Loss step:542-MSE:17.33596420288086
# Epoch: 78, Training Loss step:543-MSE:16.58232879638672
# Epoch: 78, Training Loss step:544-MSE:9.065045356750488
# Epoch: 78, Training Loss step:545-MSE:11.267510414123535
# Epoch: 78, Training Loss step:546-MSE:36.695457458496094
# Epoch: 79, Training Loss step:547-MSE:4.31700325012207
# Epoch: 79, Training Loss step:548-MSE:14.395861625671387
# Epoch: 79, Training Loss step:549-MSE:6.604620933532715
# Epoch: 79, Training Loss step:550-MSE:8.185829162597656
# Epoch: 79, Training Loss step:551-MSE:19.776437759399414
# Epoch: 79, Training Loss step:552-MSE:8.404563903808594
# Epoch: 79, Training Loss step:553-MSE:2.696424722671509
# Epoch: 80, Training Loss step:554-MSE:8.285670280456543
# Epoch: 80, Training Loss step:555-MSE:19.756694793701172
# Epoch: 80, Training Loss step:556-MSE:7.787576675415039
# Epoch: 80, Training Loss step:557-MSE:11.916614532470703
# Epoch: 80, Training Loss step:558-MSE:14.924779891967773
# Epoch: 80, Training Loss step:559-MSE:8.64445686340332
# Epoch: 80, Training Loss step:560-MSE:3.694152355194092
# Epoch: 81, Training Loss step:561-MSE:12.032488822937012
# Epoch: 81, Training Loss step:562-MSE:9.228925704956055
# Epoch: 81, Training Loss step:563-MSE:4.043814182281494
# Epoch: 81, Training Loss step:564-MSE:9.181449890136719
# Epoch: 81, Training Loss step:565-MSE:6.70359468460083
# Epoch: 81, Training Loss step:566-MSE:23.67832374572754
# Epoch: 81, Training Loss step:567-MSE:11.89445686340332
# Epoch: 82, Training Loss step:568-MSE:11.36320686340332
# Epoch: 82, Training Loss step:569-MSE:14.004422187805176
# Epoch: 82, Training Loss step:570-MSE:11.338348388671875
# Epoch: 82, Training Loss step:571-MSE:5.850272178649902
# Epoch: 82, Training Loss step:572-MSE:10.646063804626465
# Epoch: 82, Training Loss step:573-MSE:5.854646682739258
# Epoch: 82, Training Loss step:574-MSE:5.5638651847839355
# Epoch: 83, Training Loss step:575-MSE:11.265902519226074
# Epoch: 83, Training Loss step:576-MSE:20.70120620727539
# Epoch: 83, Training Loss step:577-MSE:13.452608108520508
# Epoch: 83, Training Loss step:578-MSE:5.026585578918457
# Epoch: 83, Training Loss step:579-MSE:14.544355392456055
# Epoch: 83, Training Loss step:580-MSE:7.793293476104736
# Epoch: 83, Training Loss step:581-MSE:14.731233596801758
# Epoch: 84, Training Loss step:582-MSE:8.675414085388184
# Epoch: 84, Training Loss step:583-MSE:3.7106101512908936
# Epoch: 84, Training Loss step:584-MSE:9.64216136932373
# Epoch: 84, Training Loss step:585-MSE:7.859612941741943
# Epoch: 84, Training Loss step:586-MSE:11.494783401489258
# Epoch: 84, Training Loss step:587-MSE:26.21651840209961
# Epoch: 84, Training Loss step:588-MSE:4.5518012046813965
# Epoch: 85, Training Loss step:589-MSE:15.697020530700684
# Epoch: 85, Training Loss step:590-MSE:9.094406127929688
# Epoch: 85, Training Loss step:591-MSE:3.4903337955474854
# Epoch: 85, Training Loss step:592-MSE:20.233963012695312
# Epoch: 85, Training Loss step:593-MSE:14.39100456237793
# Epoch: 85, Training Loss step:594-MSE:8.782832145690918
# Epoch: 85, Training Loss step:595-MSE:15.312192916870117
# Epoch: 86, Training Loss step:596-MSE:15.106575012207031
# Epoch: 86, Training Loss step:597-MSE:2.642077922821045
# Epoch: 86, Training Loss step:598-MSE:6.780271530151367
# Epoch: 86, Training Loss step:599-MSE:4.276381969451904
# Epoch: 86, Training Loss step:600-MSE:22.426071166992188
# Epoch: 86, Training Loss step:601-MSE:7.905118942260742
# Epoch: 86, Training Loss step:602-MSE:5.3591718673706055
# Epoch: 87, Training Loss step:603-MSE:5.560410499572754
# Epoch: 87, Training Loss step:604-MSE:8.477289199829102
# Epoch: 87, Training Loss step:605-MSE:6.773966312408447
# Epoch: 87, Training Loss step:606-MSE:9.877334594726562
# Epoch: 87, Training Loss step:607-MSE:22.267101287841797
# Epoch: 87, Training Loss step:608-MSE:5.731655120849609
# Epoch: 87, Training Loss step:609-MSE:10.74927043914795
# Epoch: 88, Training Loss step:610-MSE:5.209589958190918
# Epoch: 88, Training Loss step:611-MSE:2.4979164600372314
# Epoch: 88, Training Loss step:612-MSE:18.740459442138672
# Epoch: 88, Training Loss step:613-MSE:13.245512962341309
# Epoch: 88, Training Loss step:614-MSE:8.434308052062988
# Epoch: 88, Training Loss step:615-MSE:10.385093688964844
# Epoch: 88, Training Loss step:616-MSE:18.110572814941406
# Epoch: 89, Training Loss step:617-MSE:13.869817733764648
# Epoch: 89, Training Loss step:618-MSE:11.27643871307373
# Epoch: 89, Training Loss step:619-MSE:11.21343994140625
# Epoch: 89, Training Loss step:620-MSE:8.450489044189453
# Epoch: 89, Training Loss step:621-MSE:6.545139312744141
# Epoch: 89, Training Loss step:622-MSE:6.234313011169434
# Epoch: 89, Training Loss step:623-MSE:25.594690322875977
# Epoch: 90, Training Loss step:624-MSE:8.885998725891113
# Epoch: 90, Training Loss step:625-MSE:14.593242645263672
# Epoch: 90, Training Loss step:626-MSE:8.442896842956543
# Epoch: 90, Training Loss step:627-MSE:7.009856224060059
# Epoch: 90, Training Loss step:628-MSE:4.623942852020264
# Epoch: 90, Training Loss step:629-MSE:5.495944976806641
# Epoch: 90, Training Loss step:630-MSE:35.69049072265625
# Epoch: 91, Training Loss step:631-MSE:3.8971691131591797
# Epoch: 91, Training Loss step:632-MSE:12.957054138183594
# Epoch: 91, Training Loss step:633-MSE:6.272458076477051
# Epoch: 91, Training Loss step:634-MSE:2.3229382038116455
# Epoch: 91, Training Loss step:635-MSE:28.142024993896484
# Epoch: 91, Training Loss step:636-MSE:8.317293167114258
# Epoch: 91, Training Loss step:637-MSE:13.551942825317383
# Epoch: 92, Training Loss step:638-MSE:13.10441780090332
# Epoch: 92, Training Loss step:639-MSE:4.831716537475586
# Epoch: 92, Training Loss step:640-MSE:5.708857536315918
# Epoch: 92, Training Loss step:641-MSE:14.593838691711426
# Epoch: 92, Training Loss step:642-MSE:7.158439636230469
# Epoch: 92, Training Loss step:643-MSE:6.063717842102051
# Epoch: 92, Training Loss step:644-MSE:7.558254241943359
# Epoch: 93, Training Loss step:645-MSE:1.6085494756698608
# Epoch: 93, Training Loss step:646-MSE:6.632510662078857
# Epoch: 93, Training Loss step:647-MSE:5.093952655792236
# Epoch: 93, Training Loss step:648-MSE:4.688182353973389
# Epoch: 93, Training Loss step:649-MSE:18.821578979492188
# Epoch: 93, Training Loss step:650-MSE:13.241361618041992
# Epoch: 93, Training Loss step:651-MSE:16.43153190612793
# Epoch: 94, Training Loss step:652-MSE:5.92752742767334
# Epoch: 94, Training Loss step:653-MSE:4.068267822265625
# Epoch: 94, Training Loss step:654-MSE:10.166035652160645
# Epoch: 94, Training Loss step:655-MSE:11.659612655639648
# Epoch: 94, Training Loss step:656-MSE:15.678940773010254
# Epoch: 94, Training Loss step:657-MSE:8.513483047485352
# Epoch: 94, Training Loss step:658-MSE:1.1854612827301025
# Epoch: 95, Training Loss step:659-MSE:4.238028526306152
# Epoch: 95, Training Loss step:660-MSE:1.9703059196472168
# Epoch: 95, Training Loss step:661-MSE:4.467597007751465
# Epoch: 95, Training Loss step:662-MSE:4.0829854011535645
# Epoch: 95, Training Loss step:663-MSE:13.27759838104248
# Epoch: 95, Training Loss step:664-MSE:16.702058792114258
# Epoch: 95, Training Loss step:665-MSE:17.57089614868164
# Epoch: 96, Training Loss step:666-MSE:16.352384567260742
# Epoch: 96, Training Loss step:667-MSE:6.5286760330200195
# Epoch: 96, Training Loss step:668-MSE:5.818638801574707
# Epoch: 96, Training Loss step:669-MSE:7.889217376708984
# Epoch: 96, Training Loss step:670-MSE:5.265922546386719
# Epoch: 96, Training Loss step:671-MSE:13.703129768371582
# Epoch: 96, Training Loss step:672-MSE:5.145077705383301
# Epoch: 97, Training Loss step:673-MSE:14.860074996948242
# Epoch: 97, Training Loss step:674-MSE:6.83123254776001
# Epoch: 97, Training Loss step:675-MSE:2.8978538513183594
# Epoch: 97, Training Loss step:676-MSE:5.242032051086426
# Epoch: 97, Training Loss step:677-MSE:8.645987510681152
# Epoch: 97, Training Loss step:678-MSE:12.73550033569336
# Epoch: 97, Training Loss step:679-MSE:8.980633735656738
# Epoch: 98, Training Loss step:680-MSE:3.702857732772827
# Epoch: 98, Training Loss step:681-MSE:8.182038307189941
# Epoch: 98, Training Loss step:682-MSE:6.083765983581543
# Epoch: 98, Training Loss step:683-MSE:17.67212677001953
# Epoch: 98, Training Loss step:684-MSE:8.380101203918457
# Epoch: 98, Training Loss step:685-MSE:5.612954616546631
# Epoch: 98, Training Loss step:686-MSE:3.069284200668335
# Epoch: 99, Training Loss step:687-MSE:6.586071491241455
# Epoch: 99, Training Loss step:688-MSE:5.551227569580078
# Epoch: 99, Training Loss step:689-MSE:7.689182281494141
# Epoch: 99, Training Loss step:690-MSE:8.868997573852539
# Epoch: 99, Training Loss step:691-MSE:6.874446868896484
# Epoch: 99, Training Loss step:692-MSE:15.357748031616211
# Epoch: 99, Training Loss step:693-MSE:19.250301361083984
# Epoch: 100, Training Loss step:694-MSE:16.88487434387207
# Epoch: 100, Training Loss step:695-MSE:8.079086303710938
# Epoch: 100, Training Loss step:696-MSE:8.262779235839844
# Epoch: 100, Training Loss step:697-MSE:1.7222769260406494
# Epoch: 100, Training Loss step:698-MSE:11.206527709960938
# Epoch: 100, Training Loss step:699-MSE:8.552284240722656
# Epoch: 100, Training Loss step:700-MSE:1.04311203956604
# Epoch: 101, Training Loss step:701-MSE:5.044314861297607
# Epoch: 101, Training Loss step:702-MSE:3.245509624481201
# Epoch: 101, Training Loss step:703-MSE:9.513132095336914
# Epoch: 101, Training Loss step:704-MSE:6.476284027099609
# Epoch: 101, Training Loss step:705-MSE:7.131120681762695
# Epoch: 101, Training Loss step:706-MSE:8.335384368896484
# Epoch: 101, Training Loss step:707-MSE:28.533889770507812
# Epoch: 102, Training Loss step:708-MSE:10.574464797973633
# Epoch: 102, Training Loss step:709-MSE:5.480390548706055
# Epoch: 102, Training Loss step:710-MSE:6.36853551864624
# Epoch: 102, Training Loss step:711-MSE:11.328926086425781
# Epoch: 102, Training Loss step:712-MSE:13.239401817321777
# Epoch: 102, Training Loss step:713-MSE:4.295661449432373
# Epoch: 102, Training Loss step:714-MSE:4.608340263366699
# Epoch: 103, Training Loss step:715-MSE:8.725207328796387
# Epoch: 103, Training Loss step:716-MSE:3.6060428619384766
# Epoch: 103, Training Loss step:717-MSE:3.818772554397583
# Epoch: 103, Training Loss step:718-MSE:5.860185146331787
# Epoch: 103, Training Loss step:719-MSE:11.457748413085938
# Epoch: 103, Training Loss step:720-MSE:6.578627109527588
# Epoch: 103, Training Loss step:721-MSE:4.680569648742676
# Epoch: 104, Training Loss step:722-MSE:11.361855506896973
# Epoch: 104, Training Loss step:723-MSE:2.7698168754577637
# Epoch: 104, Training Loss step:724-MSE:4.025877952575684
# Epoch: 104, Training Loss step:725-MSE:4.864214897155762
# Epoch: 104, Training Loss step:726-MSE:10.85068130493164
# Epoch: 104, Training Loss step:727-MSE:8.350812911987305
# Epoch: 104, Training Loss step:728-MSE:2.4343278408050537
# Epoch: 105, Training Loss step:729-MSE:3.6355082988739014
# Epoch: 105, Training Loss step:730-MSE:3.182490587234497
# Epoch: 105, Training Loss step:731-MSE:5.900732040405273
# Epoch: 105, Training Loss step:732-MSE:20.648731231689453
# Epoch: 105, Training Loss step:733-MSE:12.39852237701416
# Epoch: 105, Training Loss step:734-MSE:5.266282558441162
# Epoch: 105, Training Loss step:735-MSE:5.980170726776123
# Epoch: 106, Training Loss step:736-MSE:4.340278148651123
# Epoch: 106, Training Loss step:737-MSE:6.406999588012695
# Epoch: 106, Training Loss step:738-MSE:9.889263153076172
# Epoch: 106, Training Loss step:739-MSE:5.071516990661621
# Epoch: 106, Training Loss step:740-MSE:2.8706631660461426
# Epoch: 106, Training Loss step:741-MSE:14.269285202026367
# Epoch: 106, Training Loss step:742-MSE:0.7897016406059265
# Epoch: 107, Training Loss step:743-MSE:9.430292129516602
# Epoch: 107, Training Loss step:744-MSE:5.728160381317139
# Epoch: 107, Training Loss step:745-MSE:8.858842849731445
# Epoch: 107, Training Loss step:746-MSE:6.739805698394775
# Epoch: 107, Training Loss step:747-MSE:5.716972351074219
# Epoch: 107, Training Loss step:748-MSE:16.411998748779297
# Epoch: 107, Training Loss step:749-MSE:3.130364179611206
# Epoch: 108, Training Loss step:750-MSE:6.713944435119629
# Epoch: 108, Training Loss step:751-MSE:2.4652068614959717
# Epoch: 108, Training Loss step:752-MSE:5.765798568725586
# Epoch: 108, Training Loss step:753-MSE:3.5565037727355957
# Epoch: 108, Training Loss step:754-MSE:8.934662818908691
# Epoch: 108, Training Loss step:755-MSE:14.99567985534668
# Epoch: 108, Training Loss step:756-MSE:5.393641948699951
# Epoch: 109, Training Loss step:757-MSE:6.586931228637695
# Epoch: 109, Training Loss step:758-MSE:18.49457359313965
# Epoch: 109, Training Loss step:759-MSE:6.679370880126953
# Epoch: 109, Training Loss step:760-MSE:5.668361186981201
# Epoch: 109, Training Loss step:761-MSE:9.44141674041748
# Epoch: 109, Training Loss step:762-MSE:6.203701972961426
# Epoch: 109, Training Loss step:763-MSE:8.223550796508789
# Epoch: 110, Training Loss step:764-MSE:5.499593734741211
# Epoch: 110, Training Loss step:765-MSE:5.073547840118408
# Epoch: 110, Training Loss step:766-MSE:17.559831619262695
# Epoch: 110, Training Loss step:767-MSE:4.169200897216797
# Epoch: 110, Training Loss step:768-MSE:8.470426559448242
# Epoch: 110, Training Loss step:769-MSE:4.294617652893066
# Epoch: 110, Training Loss step:770-MSE:12.20011043548584
# Epoch: 111, Training Loss step:771-MSE:4.421134948730469
# Epoch: 111, Training Loss step:772-MSE:14.0
# Epoch: 111, Training Loss step:773-MSE:4.382828712463379
# Epoch: 111, Training Loss step:774-MSE:8.174004554748535
# Epoch: 111, Training Loss step:775-MSE:7.122657299041748
# Epoch: 111, Training Loss step:776-MSE:8.672748565673828
# Epoch: 111, Training Loss step:777-MSE:3.7798871994018555
# Epoch: 112, Training Loss step:778-MSE:11.674943923950195
# Epoch: 112, Training Loss step:779-MSE:3.6443519592285156
# Epoch: 112, Training Loss step:780-MSE:5.573200702667236
# Epoch: 112, Training Loss step:781-MSE:12.698195457458496
# Epoch: 112, Training Loss step:782-MSE:6.364363193511963
# Epoch: 112, Training Loss step:783-MSE:8.033682823181152
# Epoch: 112, Training Loss step:784-MSE:4.392766952514648
# Epoch: 113, Training Loss step:785-MSE:4.114562034606934
# Epoch: 113, Training Loss step:786-MSE:10.550310134887695
# Epoch: 113, Training Loss step:787-MSE:3.269484519958496
# Epoch: 113, Training Loss step:788-MSE:9.646865844726562
# Epoch: 113, Training Loss step:789-MSE:14.619597434997559
# Epoch: 113, Training Loss step:790-MSE:7.521054267883301
# Epoch: 113, Training Loss step:791-MSE:3.408501386642456
# Epoch: 114, Training Loss step:792-MSE:9.41189193725586
# Epoch: 114, Training Loss step:793-MSE:7.744807720184326
# Epoch: 114, Training Loss step:794-MSE:14.456573486328125
# Epoch: 114, Training Loss step:795-MSE:3.50004506111145
# Epoch: 114, Training Loss step:796-MSE:6.117308616638184
# Epoch: 114, Training Loss step:797-MSE:5.27268123626709
# Epoch: 114, Training Loss step:798-MSE:7.098546981811523
# Epoch: 115, Training Loss step:799-MSE:4.865570545196533
# Epoch: 115, Training Loss step:800-MSE:11.53490924835205
# Epoch: 115, Training Loss step:801-MSE:14.200224876403809
# Epoch: 115, Training Loss step:802-MSE:5.824219703674316
# Epoch: 115, Training Loss step:803-MSE:8.997767448425293
# Epoch: 115, Training Loss step:804-MSE:6.274132251739502
# Epoch: 115, Training Loss step:805-MSE:6.449210166931152
# Epoch: 116, Training Loss step:806-MSE:12.031387329101562
# Epoch: 116, Training Loss step:807-MSE:2.952794075012207
# Epoch: 116, Training Loss step:808-MSE:4.906862258911133
# Epoch: 116, Training Loss step:809-MSE:13.07579231262207
# Epoch: 116, Training Loss step:810-MSE:3.204052209854126
# Epoch: 116, Training Loss step:811-MSE:11.749273300170898
# Epoch: 116, Training Loss step:812-MSE:3.398407220840454
# Epoch: 117, Training Loss step:813-MSE:9.133681297302246
# Epoch: 117, Training Loss step:814-MSE:1.5292205810546875
# Epoch: 117, Training Loss step:815-MSE:8.535467147827148
# Epoch: 117, Training Loss step:816-MSE:12.50888729095459
# Epoch: 117, Training Loss step:817-MSE:4.937066078186035
# Epoch: 117, Training Loss step:818-MSE:3.7166154384613037
# Epoch: 117, Training Loss step:819-MSE:2.7596027851104736
# Epoch: 118, Training Loss step:820-MSE:7.902365684509277
# Epoch: 118, Training Loss step:821-MSE:3.5649566650390625
# Epoch: 118, Training Loss step:822-MSE:4.512475967407227
# Epoch: 118, Training Loss step:823-MSE:11.288110733032227
# Epoch: 118, Training Loss step:824-MSE:6.003608703613281
# Epoch: 118, Training Loss step:825-MSE:5.24956750869751
# Epoch: 118, Training Loss step:826-MSE:2.8601796627044678
# Epoch: 119, Training Loss step:827-MSE:2.3179187774658203
# Epoch: 119, Training Loss step:828-MSE:9.748601913452148
# Epoch: 119, Training Loss step:829-MSE:7.551266193389893
# Epoch: 119, Training Loss step:830-MSE:2.393486499786377
# Epoch: 119, Training Loss step:831-MSE:5.090913772583008
# Epoch: 119, Training Loss step:832-MSE:11.513121604919434
# Epoch: 119, Training Loss step:833-MSE:10.224287033081055
# Epoch: 120, Training Loss step:834-MSE:6.209986686706543
# Epoch: 120, Training Loss step:835-MSE:3.5829451084136963
# Epoch: 120, Training Loss step:836-MSE:1.532066822052002
# Epoch: 120, Training Loss step:837-MSE:11.467767715454102
# Epoch: 120, Training Loss step:838-MSE:11.852155685424805
# Epoch: 120, Training Loss step:839-MSE:3.725637674331665
# Epoch: 120, Training Loss step:840-MSE:9.034361839294434
# Epoch: 121, Training Loss step:841-MSE:5.85863733291626
# Epoch: 121, Training Loss step:842-MSE:5.891888618469238
# Epoch: 121, Training Loss step:843-MSE:5.242294788360596
# Epoch: 121, Training Loss step:844-MSE:11.818603515625
# Epoch: 121, Training Loss step:845-MSE:3.0949363708496094
# Epoch: 121, Training Loss step:846-MSE:10.922590255737305
# Epoch: 121, Training Loss step:847-MSE:14.818580627441406
# Epoch: 122, Training Loss step:848-MSE:15.05203914642334
# Epoch: 122, Training Loss step:849-MSE:5.690005779266357
# Epoch: 122, Training Loss step:850-MSE:10.14018440246582
# Epoch: 122, Training Loss step:851-MSE:2.0004758834838867
# Epoch: 122, Training Loss step:852-MSE:1.8215522766113281
# ...
# Epoch: 462, Training Loss step:3229-MSE:0.4212421774864197
# Epoch: 462, Training Loss step:3230-MSE:1.201565146446228
# Epoch: 462, Training Loss step:3231-MSE:3.2250115871429443
# Epoch: 462, Training Loss step:3232-MSE:1.2784321308135986
# Epoch: 462, Training Loss step:3233-MSE:1.7799497842788696
# Epoch: 462, Training Loss step:3234-MSE:1.3910776376724243
# Epoch: 463, Training Loss step:3235-MSE:1.375836730003357
# Epoch: 463, Training Loss step:3236-MSE:1.1420178413391113
# Epoch: 463, Training Loss step:3237-MSE:1.578176498413086
# Epoch: 463, Training Loss step:3238-MSE:0.8026293516159058
# Epoch: 463, Training Loss step:3239-MSE:3.838313102722168
# Epoch: 463, Training Loss step:3240-MSE:0.8838962316513062
# Epoch: 463, Training Loss step:3241-MSE:1.3793938159942627
# Epoch: 464, Training Loss step:3242-MSE:1.3785794973373413
# Epoch: 464, Training Loss step:3243-MSE:2.939605236053467
# Epoch: 464, Training Loss step:3244-MSE:1.3200044631958008
# Epoch: 464, Training Loss step:3245-MSE:1.1534347534179688
# Epoch: 464, Training Loss step:3246-MSE:3.054612398147583
# Epoch: 464, Training Loss step:3247-MSE:0.2010922133922577
# Epoch: 464, Training Loss step:3248-MSE:1.1933753490447998
# Epoch: 465, Training Loss step:3249-MSE:2.6827192306518555
# Epoch: 465, Training Loss step:3250-MSE:0.5535749793052673
# Epoch: 465, Training Loss step:3251-MSE:0.6982318162918091
# Epoch: 465, Training Loss step:3252-MSE:1.0938894748687744
# Epoch: 465, Training Loss step:3253-MSE:0.7745035886764526
# Epoch: 465, Training Loss step:3254-MSE:1.6662769317626953
# Epoch: 465, Training Loss step:3255-MSE:2.0198960304260254
# Epoch: 466, Training Loss step:3256-MSE:1.179089069366455
# Epoch: 466, Training Loss step:3257-MSE:3.2676172256469727
# Epoch: 466, Training Loss step:3258-MSE:1.0421040058135986
# Epoch: 466, Training Loss step:3259-MSE:1.5318224430084229
# Epoch: 466, Training Loss step:3260-MSE:1.176142930984497
# Epoch: 466, Training Loss step:3261-MSE:1.0197441577911377
# Epoch: 466, Training Loss step:3262-MSE:1.4120153188705444
# Epoch: 467, Training Loss step:3263-MSE:2.3770864009857178
# Epoch: 467, Training Loss step:3264-MSE:0.5167535543441772
# Epoch: 467, Training Loss step:3265-MSE:0.7386664152145386
# Epoch: 467, Training Loss step:3266-MSE:2.0286757946014404
# Epoch: 467, Training Loss step:3267-MSE:1.0604678392410278
# Epoch: 467, Training Loss step:3268-MSE:0.6704905033111572
# Epoch: 467, Training Loss step:3269-MSE:1.8392200469970703
# Epoch: 468, Training Loss step:3270-MSE:0.6632419228553772
# Epoch: 468, Training Loss step:3271-MSE:0.3605165183544159
# Epoch: 468, Training Loss step:3272-MSE:1.647071123123169
# Epoch: 468, Training Loss step:3273-MSE:1.6013762950897217
# Epoch: 468, Training Loss step:3274-MSE:2.18532133102417
# Epoch: 468, Training Loss step:3275-MSE:0.6531640291213989
# Epoch: 468, Training Loss step:3276-MSE:3.2410523891448975
# Epoch: 469, Training Loss step:3277-MSE:0.37055402994155884
# Epoch: 469, Training Loss step:3278-MSE:1.8494954109191895
# Epoch: 469, Training Loss step:3279-MSE:0.5178259611129761
# Epoch: 469, Training Loss step:3280-MSE:2.6304614543914795
# Epoch: 469, Training Loss step:3281-MSE:0.7092247605323792
# Epoch: 469, Training Loss step:3282-MSE:0.722858190536499
# Epoch: 469, Training Loss step:3283-MSE:1.5134193897247314
# Epoch: 470, Training Loss step:3284-MSE:1.8362886905670166
# Epoch: 470, Training Loss step:3285-MSE:1.4008448123931885
# Epoch: 470, Training Loss step:3286-MSE:2.7495968341827393
# Epoch: 470, Training Loss step:3287-MSE:0.7298287749290466
# Epoch: 470, Training Loss step:3288-MSE:1.306102991104126
# Epoch: 470, Training Loss step:3289-MSE:1.8804682493209839
# Epoch: 470, Training Loss step:3290-MSE:0.8171554207801819
# Epoch: 471, Training Loss step:3291-MSE:1.379971981048584
# Epoch: 471, Training Loss step:3292-MSE:0.5623166561126709
# Epoch: 471, Training Loss step:3293-MSE:1.6805123090744019
# Epoch: 471, Training Loss step:3294-MSE:0.41171181201934814
# Epoch: 471, Training Loss step:3295-MSE:0.9264733791351318
# Epoch: 471, Training Loss step:3296-MSE:0.45433396100997925
# Epoch: 471, Training Loss step:3297-MSE:0.7388542890548706
# Epoch: 472, Training Loss step:3298-MSE:2.883049964904785
# Epoch: 472, Training Loss step:3299-MSE:0.6595672369003296
# Epoch: 472, Training Loss step:3300-MSE:1.7945908308029175
# Epoch: 472, Training Loss step:3301-MSE:0.4712662696838379
# Epoch: 472, Training Loss step:3302-MSE:1.0068442821502686
# Epoch: 472, Training Loss step:3303-MSE:1.43080735206604
# Epoch: 472, Training Loss step:3304-MSE:1.350510835647583
# Epoch: 473, Training Loss step:3305-MSE:1.7617719173431396
# Epoch: 473, Training Loss step:3306-MSE:1.2297167778015137
# Epoch: 473, Training Loss step:3307-MSE:1.7060630321502686
# Epoch: 473, Training Loss step:3308-MSE:3.535102128982544
# Epoch: 473, Training Loss step:3309-MSE:0.7313233017921448
# Epoch: 473, Training Loss step:3310-MSE:1.002861738204956
# Epoch: 473, Training Loss step:3311-MSE:1.7431044578552246
# Epoch: 474, Training Loss step:3312-MSE:4.2560133934021
# Epoch: 474, Training Loss step:3313-MSE:0.262726366519928
# Epoch: 474, Training Loss step:3314-MSE:1.4552701711654663
# Epoch: 474, Training Loss step:3315-MSE:0.7166351675987244
# Epoch: 474, Training Loss step:3316-MSE:0.707602858543396
# Epoch: 474, Training Loss step:3317-MSE:1.1114410161972046
# Epoch: 474, Training Loss step:3318-MSE:0.4291820526123047
# Epoch: 475, Training Loss step:3319-MSE:2.1431589126586914
# Epoch: 475, Training Loss step:3320-MSE:2.1814067363739014
# Epoch: 475, Training Loss step:3321-MSE:0.8656167984008789
# Epoch: 475, Training Loss step:3322-MSE:1.830206036567688
# Epoch: 475, Training Loss step:3323-MSE:0.7274649143218994
# Epoch: 475, Training Loss step:3324-MSE:2.642350196838379
# Epoch: 475, Training Loss step:3325-MSE:2.844125270843506
# Epoch: 476, Training Loss step:3326-MSE:0.8584113121032715
# Epoch: 476, Training Loss step:3327-MSE:0.7114948034286499
# Epoch: 476, Training Loss step:3328-MSE:0.8900593519210815
# Epoch: 476, Training Loss step:3329-MSE:0.967153787612915
# Epoch: 476, Training Loss step:3330-MSE:1.2187048196792603
# Epoch: 476, Training Loss step:3331-MSE:0.6076999306678772
# Epoch: 476, Training Loss step:3332-MSE:0.31996554136276245
# Epoch: 477, Training Loss step:3333-MSE:1.0051758289337158
# Epoch: 477, Training Loss step:3334-MSE:1.2164331674575806
# Epoch: 477, Training Loss step:3335-MSE:1.4792604446411133
# Epoch: 477, Training Loss step:3336-MSE:0.578149676322937
# Epoch: 477, Training Loss step:3337-MSE:2.0357584953308105
# Epoch: 477, Training Loss step:3338-MSE:0.521190345287323
# Epoch: 477, Training Loss step:3339-MSE:1.127621054649353
# Epoch: 478, Training Loss step:3340-MSE:1.6697673797607422
# Epoch: 478, Training Loss step:3341-MSE:0.43871399760246277
# Epoch: 478, Training Loss step:3342-MSE:1.60915207862854
# Epoch: 478, Training Loss step:3343-MSE:1.2065606117248535
# Epoch: 478, Training Loss step:3344-MSE:1.134486198425293
# Epoch: 478, Training Loss step:3345-MSE:0.9551019072532654
# Epoch: 478, Training Loss step:3346-MSE:1.1504619121551514
# Epoch: 479, Training Loss step:3347-MSE:0.7367889881134033
# Epoch: 479, Training Loss step:3348-MSE:1.335014820098877
# Epoch: 479, Training Loss step:3349-MSE:2.501984119415283
# Epoch: 479, Training Loss step:3350-MSE:1.9828541278839111
# Epoch: 479, Training Loss step:3351-MSE:4.578071594238281
# Epoch: 479, Training Loss step:3352-MSE:0.8048498630523682
# Epoch: 479, Training Loss step:3353-MSE:1.251684546470642
# Epoch: 480, Training Loss step:3354-MSE:1.6729445457458496
# Epoch: 480, Training Loss step:3355-MSE:0.7341194748878479
# Epoch: 480, Training Loss step:3356-MSE:1.445302963256836
# Epoch: 480, Training Loss step:3357-MSE:1.3382539749145508
# Epoch: 480, Training Loss step:3358-MSE:0.5746124982833862
# Epoch: 480, Training Loss step:3359-MSE:0.779532790184021
# Epoch: 480, Training Loss step:3360-MSE:0.7464590668678284
# Epoch: 481, Training Loss step:3361-MSE:1.1066944599151611
# Epoch: 481, Training Loss step:3362-MSE:2.573617935180664
# Epoch: 481, Training Loss step:3363-MSE:0.9562438726425171
# Epoch: 481, Training Loss step:3364-MSE:0.8557031750679016
# Epoch: 481, Training Loss step:3365-MSE:0.9816809892654419
# Epoch: 481, Training Loss step:3366-MSE:3.2737927436828613
# Epoch: 481, Training Loss step:3367-MSE:1.2156838178634644
# Epoch: 482, Training Loss step:3368-MSE:0.8352534174919128
# Epoch: 482, Training Loss step:3369-MSE:0.43388107419013977
# Epoch: 482, Training Loss step:3370-MSE:1.5469107627868652
# Epoch: 482, Training Loss step:3371-MSE:1.3632512092590332
# Epoch: 482, Training Loss step:3372-MSE:0.4421645402908325
# Epoch: 482, Training Loss step:3373-MSE:1.2882510423660278
# Epoch: 482, Training Loss step:3374-MSE:2.507521152496338
# Epoch: 483, Training Loss step:3375-MSE:1.0548851490020752
# Epoch: 483, Training Loss step:3376-MSE:1.2129093408584595
# Epoch: 483, Training Loss step:3377-MSE:0.9018726348876953
# Epoch: 483, Training Loss step:3378-MSE:1.1106868982315063
# Epoch: 483, Training Loss step:3379-MSE:0.5912243127822876
# Epoch: 483, Training Loss step:3380-MSE:1.0794446468353271
# Epoch: 483, Training Loss step:3381-MSE:0.8942986130714417
# Epoch: 484, Training Loss step:3382-MSE:1.2005548477172852
# Epoch: 484, Training Loss step:3383-MSE:0.6050397753715515
# Epoch: 484, Training Loss step:3384-MSE:0.9064673781394958
# Epoch: 484, Training Loss step:3385-MSE:0.5693547129631042
# Epoch: 484, Training Loss step:3386-MSE:0.6696377992630005
# Epoch: 484, Training Loss step:3387-MSE:2.336491823196411
# Epoch: 484, Training Loss step:3388-MSE:1.3812376260757446
# Epoch: 485, Training Loss step:3389-MSE:0.523942232131958
# Epoch: 485, Training Loss step:3390-MSE:0.7305712103843689
# Epoch: 485, Training Loss step:3391-MSE:0.2469581961631775
# Epoch: 485, Training Loss step:3392-MSE:2.3824663162231445
# Epoch: 485, Training Loss step:3393-MSE:2.140153646469116
# Epoch: 485, Training Loss step:3394-MSE:1.0963038206100464
# Epoch: 485, Training Loss step:3395-MSE:2.073439359664917
# Epoch: 486, Training Loss step:3396-MSE:0.6033423542976379
# Epoch: 486, Training Loss step:3397-MSE:1.2285840511322021
# Epoch: 486, Training Loss step:3398-MSE:0.42121660709381104
# Epoch: 486, Training Loss step:3399-MSE:1.3152873516082764
# Epoch: 486, Training Loss step:3400-MSE:1.3919001817703247
# Epoch: 486, Training Loss step:3401-MSE:0.6252827048301697
# Epoch: 486, Training Loss step:3402-MSE:1.8756215572357178
# Epoch: 487, Training Loss step:3403-MSE:0.7292031645774841
# Epoch: 487, Training Loss step:3404-MSE:1.5689961910247803
# Epoch: 487, Training Loss step:3405-MSE:0.9809874296188354
# Epoch: 487, Training Loss step:3406-MSE:0.7275478839874268
# Epoch: 487, Training Loss step:3407-MSE:0.7587496042251587
# Epoch: 487, Training Loss step:3408-MSE:0.9282673597335815
# Epoch: 487, Training Loss step:3409-MSE:2.2501027584075928
# Epoch: 488, Training Loss step:3410-MSE:3.8201799392700195
# Epoch: 488, Training Loss step:3411-MSE:1.6745948791503906
# Epoch: 488, Training Loss step:3412-MSE:0.5809907913208008
# Epoch: 488, Training Loss step:3413-MSE:1.6547918319702148
# Epoch: 488, Training Loss step:3414-MSE:0.527363657951355
# Epoch: 488, Training Loss step:3415-MSE:0.41377267241477966
# Epoch: 488, Training Loss step:3416-MSE:0.34398725628852844
# Epoch: 489, Training Loss step:3417-MSE:1.3648097515106201
# Epoch: 489, Training Loss step:3418-MSE:1.0614478588104248
# Epoch: 489, Training Loss step:3419-MSE:0.1750168353319168
# Epoch: 489, Training Loss step:3420-MSE:1.981507420539856
# Epoch: 489, Training Loss step:3421-MSE:1.3710191249847412
# Epoch: 489, Training Loss step:3422-MSE:0.4160069227218628
# Epoch: 489, Training Loss step:3423-MSE:1.051736831665039
# Epoch: 490, Training Loss step:3424-MSE:0.9656581878662109
# Epoch: 490, Training Loss step:3425-MSE:0.8082746267318726
# Epoch: 490, Training Loss step:3426-MSE:1.5708900690078735
# Epoch: 490, Training Loss step:3427-MSE:1.2182621955871582
# Epoch: 490, Training Loss step:3428-MSE:1.2284791469573975
# Epoch: 490, Training Loss step:3429-MSE:1.655531406402588
# Epoch: 490, Training Loss step:3430-MSE:1.021822452545166
# Epoch: 491, Training Loss step:3431-MSE:0.6636996269226074
# Epoch: 491, Training Loss step:3432-MSE:0.8454923629760742
# Epoch: 491, Training Loss step:3433-MSE:1.1584827899932861
# Epoch: 491, Training Loss step:3434-MSE:2.1298327445983887
# Epoch: 491, Training Loss step:3435-MSE:1.5520795583724976
# Epoch: 491, Training Loss step:3436-MSE:1.5775947570800781
# Epoch: 491, Training Loss step:3437-MSE:0.37104684114456177
# Epoch: 492, Training Loss step:3438-MSE:0.5806036591529846
# Epoch: 492, Training Loss step:3439-MSE:1.248368740081787
# Epoch: 492, Training Loss step:3440-MSE:0.6945602893829346
# Epoch: 492, Training Loss step:3441-MSE:0.844356894493103
# Epoch: 492, Training Loss step:3442-MSE:1.288497805595398
# Epoch: 492, Training Loss step:3443-MSE:0.9044999480247498
# Epoch: 492, Training Loss step:3444-MSE:1.2659133672714233
# Epoch: 493, Training Loss step:3445-MSE:0.48439663648605347
# Epoch: 493, Training Loss step:3446-MSE:0.9666755795478821
# Epoch: 493, Training Loss step:3447-MSE:1.159031867980957
# Epoch: 493, Training Loss step:3448-MSE:2.11210560798645
# Epoch: 493, Training Loss step:3449-MSE:2.4182777404785156
# Epoch: 493, Training Loss step:3450-MSE:1.4807004928588867
# Epoch: 493, Training Loss step:3451-MSE:1.3945668935775757
# Epoch: 494, Training Loss step:3452-MSE:0.5851728320121765
# Epoch: 494, Training Loss step:3453-MSE:1.1827725172042847
# Epoch: 494, Training Loss step:3454-MSE:1.2042796611785889
# Epoch: 494, Training Loss step:3455-MSE:1.800272822380066
# Epoch: 494, Training Loss step:3456-MSE:0.5848110318183899
# Epoch: 494, Training Loss step:3457-MSE:1.3466510772705078
# Epoch: 494, Training Loss step:3458-MSE:0.21282516419887543
# Epoch: 495, Training Loss step:3459-MSE:0.25790318846702576
# Epoch: 495, Training Loss step:3460-MSE:0.8229067325592041
# Epoch: 495, Training Loss step:3461-MSE:3.1471610069274902
# Epoch: 495, Training Loss step:3462-MSE:1.5939997434616089
# Epoch: 495, Training Loss step:3463-MSE:1.3712811470031738
# Epoch: 495, Training Loss step:3464-MSE:0.5241711139678955
# Epoch: 495, Training Loss step:3465-MSE:2.1155288219451904
# Epoch: 496, Training Loss step:3466-MSE:0.6324849724769592
# Epoch: 496, Training Loss step:3467-MSE:0.8499757647514343
# Epoch: 496, Training Loss step:3468-MSE:1.9542638063430786
# Epoch: 496, Training Loss step:3469-MSE:1.7716166973114014
# Epoch: 496, Training Loss step:3470-MSE:0.5723157525062561
# Epoch: 496, Training Loss step:3471-MSE:1.0116013288497925
# Epoch: 496, Training Loss step:3472-MSE:1.2414222955703735
# Epoch: 497, Training Loss step:3473-MSE:0.4602329730987549
# Epoch: 497, Training Loss step:3474-MSE:1.6835955381393433
# Epoch: 497, Training Loss step:3475-MSE:1.3162167072296143
# Epoch: 497, Training Loss step:3476-MSE:0.6404248476028442
# Epoch: 497, Training Loss step:3477-MSE:0.7605931758880615
# Epoch: 497, Training Loss step:3478-MSE:1.0023760795593262
# Epoch: 497, Training Loss step:3479-MSE:1.1731994152069092
# Epoch: 498, Training Loss step:3480-MSE:0.5943887233734131
# Epoch: 498, Training Loss step:3481-MSE:0.9608783721923828
# Epoch: 498, Training Loss step:3482-MSE:2.3232035636901855
# Epoch: 498, Training Loss step:3483-MSE:0.865500807762146
# Epoch: 498, Training Loss step:3484-MSE:0.8204513788223267
# Epoch: 498, Training Loss step:3485-MSE:1.4561371803283691
# Epoch: 498, Training Loss step:3486-MSE:0.5916165113449097
# Epoch: 499, Training Loss step:3487-MSE:0.5755845308303833
# Epoch: 499, Training Loss step:3488-MSE:1.1453144550323486
# Epoch: 499, Training Loss step:3489-MSE:1.1721878051757812
# Epoch: 499, Training Loss step:3490-MSE:1.1541979312896729
# Epoch: 499, Training Loss step:3491-MSE:0.7358696460723877
# Epoch: 499, Training Loss step:3492-MSE:1.0720340013504028
# Epoch: 499, Training Loss step:3493-MSE:0.8496952652931213
# Epoch: 500, Training Loss step:3494-MSE:1.4740344285964966
# Epoch: 500, Training Loss step:3495-MSE:2.4537432193756104
# Epoch: 500, Training Loss step:3496-MSE:0.52345871925354
# Epoch: 500, Training Loss step:3497-MSE:1.4933993816375732
# Epoch: 500, Training Loss step:3498-MSE:1.4240376949310303
# Epoch: 500, Training Loss step:3499-MSE:0.9825583696365356
# Epoch: 500, Training Loss step:3500-MSE:0.4906536042690277

# %%
# loss_list may contain CUDA tensors → turn each into a Python float
loss_cpu_training = [float(l.detach().cpu()) if torch.is_tensor(l) else float(l)
            for l in training_loss]

# ── basic curve ─────────────────────────────────────────────────────────
# plt.figure(figsize=(8, 5))
# plt.plot(loss_cpu_training, label='Training loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss (MSE)')
# plt.title('Training loss vs. epoch')
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

# # ── optional: add a 5‑epoch rolling‑average smoother ───────────────────
smooth = pd.Series(loss_cpu_training).rolling(window=5, min_periods=1).mean()
plt.figure(figsize=(8, 5))
plt.plot(loss_cpu_training,  alpha=0.3, label='Raw')
plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# loss_list may contain CUDA tensors → turn each into a Python float
loss_cpu_val = [float(l.detach().cpu()) if torch.is_tensor(l) else float(l)
            for l in val_loss_list]

# ── basic curve ─────────────────────────────────────────────────────────
# plt.figure(figsize=(8, 5))
# plt.plot(loss_cpu_training, label='Training loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss (MSE)')
# plt.title('Training loss vs. epoch')
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

# # ── optional: add a 5‑epoch rolling‑average smoother ───────────────────
smooth = pd.Series(loss_cpu_val).rolling(window=5, min_periods=1).mean()
plt.figure(figsize=(8, 5))
plt.plot(loss_cpu_val,  alpha=0.3, label='Raw')
plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
loss_cpu_val
# Out:
# [143.2284698486328,
#  137.81353759765625,
#  128.42738342285156,
#  113.45722198486328,
#  92.3926773071289,
#  69.5259017944336,
#  53.86888122558594,
#  49.18877029418945,
#  49.66145324707031,
#  51.842288970947266,
#  53.540008544921875,
#  51.52516174316406,
#  50.343318939208984,
#  50.09257125854492,
#  50.06611251831055,
#  50.766571044921875,
#  50.946678161621094,
#  51.04546356201172,
#  50.31507873535156,
#  50.33121871948242,
#  50.43541717529297,
#  50.06507110595703,
#  50.04088592529297,
#  50.39194107055664,
#  50.43937301635742,
#  50.113319396972656,
#  50.09756851196289,
#  49.66896438598633,
#  49.65843963623047,
#  49.51353454589844,
#  49.33674621582031,
#  48.659912109375,
#  48.47259521484375,
#  48.482879638671875,
#  48.28047180175781,
#  48.04706573486328,
#  47.66402053833008,
#  47.24129867553711,
#  46.61570358276367,
#  46.41259765625,
#  46.28902816772461,
#  46.29378890991211,
#  45.19084930419922,
#  44.45450973510742,
#  43.45867156982422,
#  43.34608459472656,
#  43.021488189697266,
#  43.04833984375,
#  41.43204116821289,
#  40.882266998291016,
#  39.977352142333984,
#  40.10489273071289,
#  39.32586669921875,
#  38.52104187011719,
#  38.48933792114258,
#  38.37721633911133,
#  37.34810256958008,
#  36.381500244140625,
#  35.87340545654297,
#  36.34976577758789,
#  36.130470275878906,
#  35.39978790283203,
#  34.57138442993164,
#  33.86489486694336,
#  34.21074295043945,
#  34.32114791870117,
#  34.477725982666016,
#  33.68855667114258,
#  32.9366569519043,
#  32.737152099609375,
#  33.13846206665039,
#  33.33170700073242,
#  33.95502471923828,
#  33.69256591796875,
#  32.90620040893555,
#  32.3911018371582,
#  31.94500732421875,
#  32.806175231933594,
#  34.5473747253418,
#  31.836538314819336,
#  31.379150390625,
#  31.470951080322266,
#  30.966928482055664,
#  33.18047332763672,
#  32.14033889770508,
#  32.218772888183594,
#  33.49026107788086,
#  34.05527877807617,
#  34.26944351196289,
#  34.43851852416992,
#  33.4830322265625,
#  32.780941009521484,
#  31.53780746459961,
#  30.119415283203125,
#  30.7615966796875,
#  31.959152221679688,
#  33.155643463134766,
#  33.0203742980957,
#  32.946434020996094,
#  31.919137954711914,
#  31.520938873291016,
#  30.593358993530273,
#  30.219501495361328,
#  30.909372329711914,
#  31.04451560974121,
#  31.343875885009766,
#  32.3567008972168,
#  32.83430480957031,
#  32.41039276123047,
#  33.98481369018555,
#  32.44343566894531,
#  32.6668586730957,
#  31.87022590637207,
#  31.432096481323242,
#  31.502403259277344,
#  32.09530258178711,
#  32.8389892578125,
#  32.00092315673828,
#  31.25726890563965,
#  30.733304977416992,
#  30.466459274291992,
#  30.65620994567871,
#  31.471378326416016,
#  31.61465835571289,
#  32.127017974853516,
#  30.186811447143555,
#  30.433834075927734,
#  31.24985694885254,
#  30.773948669433594,
#  31.22902488708496,
#  31.9351749420166,
#  32.997493743896484,
#  33.414268493652344,
#  33.2121696472168,
#  33.29978561401367,
#  34.10574722290039,
#  32.87814712524414,
#  32.06067657470703,
#  32.701290130615234,
#  32.156768798828125,
#  32.437252044677734,
#  33.574623107910156,
#  33.023582458496094,
#  31.929443359375,
#  32.37215042114258,
#  33.135536193847656,
#  33.29227828979492,
#  33.6426887512207,
#  34.90761947631836,
#  34.2349853515625,
#  33.77842330932617,
#  34.32545852661133,
#  34.443790435791016,
#  34.72248077392578,
#  35.13051986694336,
#  36.08829879760742,
#  35.82461929321289,
#  36.31401443481445,
#  36.46800994873047,
#  35.462120056152344,
#  34.6744384765625,
#  35.51704788208008,
#  35.65542221069336,
#  35.96707534790039,
#  35.82322311401367,
#  34.80526351928711,
#  34.45381164550781,
#  34.92854309082031,
#  35.66538619995117,
#  34.012386322021484,
#  34.72901916503906,
#  33.388938903808594,
#  33.32906723022461,
#  34.80674743652344,
#  33.71051788330078,
#  35.4410400390625,
#  35.32208251953125,
#  36.67405319213867,
#  38.01351547241211,
#  37.91869354248047,
#  35.53634262084961,
#  34.73379135131836,
#  34.762596130371094,
#  35.52522659301758,
#  34.195037841796875,
#  34.90065002441406,
#  36.30615234375,
#  35.65187072753906,
#  36.30140686035156,
#  36.06775665283203,
#  35.91550827026367,
#  36.27584457397461,
#  36.504150390625,
#  36.32229232788086,
#  35.75920867919922,
#  36.61906814575195,
#  38.02863693237305,
#  35.62331008911133,
#  36.19742965698242,
#  39.735931396484375,
#  38.3686408996582,
#  35.840965270996094,
#  35.6310920715332,
#  36.606727600097656,
#  35.45536804199219,
#  37.57544708251953,
#  38.75752258300781,
#  37.93624496459961,
#  37.602867126464844,
#  37.533531188964844,
#  38.05238342285156,
#  37.202144622802734,
#  36.092254638671875,
#  37.22520065307617,
#  36.641197204589844,
#  36.9559440612793,
#  37.24753189086914,
#  37.91402816772461,
#  37.62286376953125,
#  38.215110778808594,
#  39.28116989135742,
#  38.417015075683594,
#  37.19343566894531,
#  38.269161224365234,
#  38.91486740112305,
#  38.71192932128906,
#  40.49953842163086,
#  37.99248123168945,
#  38.44485855102539,
#  38.90420150756836,
#  38.16218566894531,
#  38.79624557495117,
#  38.253448486328125,
#  36.612430572509766,
#  35.886600494384766,
#  35.51296615600586,
#  38.7809944152832,
#  37.995506286621094,
#  38.84666061401367,
#  40.05339050292969,
#  36.54970932006836,
#  37.52254104614258,
#  41.04157257080078,
#  39.240875244140625,
#  37.9638671875,
#  36.98272705078125,
#  39.75721740722656,
#  39.98104476928711,
#  39.424522399902344,
#  38.810791015625,
#  39.04825973510742,
#  39.51007843017578,
#  40.70095443725586,
#  38.73704147338867,
#  37.66315460205078,
#  40.8460578918457,
#  40.274620056152344,
#  37.2631721496582,
#  38.62960433959961,
#  38.317779541015625,
#  37.49324417114258,
#  37.88410568237305,
#  38.34120559692383,
#  38.39073944091797,
#  37.6644287109375,
#  38.39159393310547,
#  37.88832473754883,
#  37.77665328979492,
#  39.22475814819336,
#  39.74857711791992,
#  38.32554244995117,
#  38.797786712646484,
#  37.00809097290039,
#  36.350799560546875,
#  37.184974670410156,
#  39.31155014038086,
#  37.656394958496094,
#  40.5532341003418,
#  37.68887710571289,
#  35.612266540527344,
#  38.00680160522461,
#  36.93980026245117,
#  36.3502311706543,
#  36.038475036621094,
#  36.542938232421875,
#  38.197776794433594,
#  37.851776123046875,
#  36.432029724121094,
#  35.59791564941406,
#  35.54924392700195,
#  35.632530212402344,
#  35.284912109375,
#  35.30952072143555,
#  38.45948028564453,
#  39.03431701660156,
#  36.547080993652344,
#  36.08068084716797,
#  35.00001525878906,
#  36.022579193115234,
#  37.2647705078125,
#  37.439048767089844,
#  38.5451545715332,
#  38.59403610229492,
#  37.063785552978516,
#  35.422386169433594,
#  36.480831146240234,
#  37.60409164428711,
#  37.1336555480957,
#  37.08354949951172,
#  38.15463638305664,
#  38.904300689697266,
#  37.60985565185547,
#  36.59473419189453,
#  36.47092056274414,
#  37.078163146972656,
#  35.358760833740234,
#  35.7071533203125,
#  36.00558853149414,
#  36.38901901245117,
#  37.14298629760742,
#  36.33552932739258,
#  36.64458465576172,
#  37.868934631347656,
#  36.4589729309082,
#  35.618953704833984,
#  36.509376525878906,
#  33.76084899902344,
#  33.63690948486328,
#  36.37125015258789,
#  36.26783752441406,
#  35.59721374511719,
#  37.189144134521484,
#  36.30910110473633,
#  35.588626861572266,
#  36.76020050048828,
#  36.9729118347168,
#  34.83822250366211,
#  34.7564582824707,
#  35.39055252075195,
#  33.734100341796875,
#  32.48969268798828,
#  33.28017044067383,
#  32.96261215209961,
#  34.08888626098633,
#  33.78900146484375,
#  33.22860336303711,
#  34.969905853271484,
#  35.19057846069336,
#  36.57136917114258,
#  36.57048034667969,
#  36.42460250854492,
#  35.37519836425781,
#  35.630157470703125,
#  34.960994720458984,
#  34.347511291503906,
#  33.6694450378418,
#  33.81220245361328,
#  33.86104965209961,
#  34.01095199584961,
#  34.01778793334961,
#  33.733882904052734,
#  33.544090270996094,
#  34.60536193847656,
#  33.621761322021484,
#  34.76791763305664,
#  34.14268112182617,
#  33.40925598144531,
#  34.01030731201172,
#  34.100399017333984,
#  33.28915023803711,
#  34.13853073120117,
#  32.65214920043945,
#  33.353084564208984,
#  34.05594253540039,
#  33.46780776977539,
#  33.08130645751953,
#  32.93327331542969,
#  32.71908187866211,
#  33.20097732543945,
#  32.35403060913086,
#  34.1691780090332,
#  33.97050857543945,
#  31.588592529296875,
#  31.534122467041016,
#  32.59566879272461,
#  32.84636306762695,
#  33.06284713745117,
#  32.43397521972656,
#  32.76203536987305,
#  32.06349563598633,
#  32.900482177734375,
#  32.51856231689453,
#  33.05827713012695,
#  33.31682205200195,
#  33.70296859741211,
#  32.59127426147461,
#  32.57819366455078,
#  32.31722640991211,
#  32.129817962646484,
#  32.79838943481445,
#  32.3192024230957,
#  31.795175552368164,
#  32.89728927612305,
#  33.07989501953125,
#  34.06317138671875,
#  36.30242156982422,
#  32.35951614379883,
#  32.06046676635742,
#  33.23188781738281,
#  32.38750076293945,
#  34.06826400756836,
#  34.494972229003906,
#  34.147396087646484,
#  34.03224182128906,
#  33.720420837402344,
#  33.05958557128906,
#  32.66756820678711,
#  33.170372009277344,
#  34.18620681762695,
#  34.14702606201172,
#  33.12848663330078,
#  34.27338409423828,
#  32.23402404785156,
#  31.55961799621582,
#  31.836402893066406,
#  34.43548583984375,
#  32.32015609741211,
#  32.518436431884766,
#  32.40235137939453,
#  31.906269073486328,
#  32.37264633178711,
#  31.518646240234375,
#  30.54241180419922,
#  30.45631217956543,
#  31.10068702697754,
#  31.75316619873047,
#  30.683738708496094,
#  31.377885818481445,
#  32.88806915283203,
#  30.81170654296875,
#  32.59278869628906,
#  32.35129928588867,
#  32.891361236572266,
#  33.07874298095703,
#  31.645286560058594,
#  31.09052085876465,
#  29.75808334350586,
#  31.071195602416992,
#  32.1298713684082,
#  30.663471221923828,
#  31.15877342224121,
#  32.21854782104492,
#  31.122177124023438,
#  32.37290573120117,
#  31.19706916809082,
#  30.979448318481445,
#  31.90083885192871,
#  33.21908187866211,
#  32.98118209838867,
#  30.733154296875,
#  30.916156768798828,
#  30.822500228881836,
#  30.028217315673828,
#  30.920448303222656,
#  32.009857177734375,
#  30.392040252685547,
#  30.11915397644043,
#  29.9655704498291,
#  30.545257568359375,
#  32.388999938964844,
#  31.386991500854492,
#  30.397132873535156,
#  30.181230545043945,
#  30.11403465270996,
#  30.691139221191406,
#  32.09708023071289,
#  31.88425064086914,
#  32.113853454589844,
#  30.247711181640625,
#  30.410619735717773,
#  29.829792022705078,
#  30.362123489379883,
#  30.12120246887207,
#  29.40987205505371,
#  29.475969314575195,
#  30.013593673706055,
#  29.859638214111328,
#  31.276004791259766,
#  31.16026496887207,
#  30.52200698852539,
#  29.786312103271484,
#  30.252487182617188,
#  29.901195526123047,
#  28.196107864379883,
#  28.07171630859375,
#  29.6640625,
#  30.177961349487305,
#  29.747318267822266,
#  28.780229568481445,
#  28.913352966308594]

# %%
# model.load_state_dict(best_state)

# ── 4.  Evaluate on the test set ─────────────────────────────────────────
model.eval()
with torch.no_grad():
    preds_z = model(X_test_t.to(device)).cpu().numpy().ravel()

#preds = y_scaler.inverse_transform(preds_z.reshape(-1, 1)).ravel()

rmse_nn = np.sqrt(mean_squared_error(y_test_flood, preds_z))
r2_nn   = r2_score(y_test_flood, preds)

print(f"PyTorch NN  RMSE: {rmse_nn:,.2f}   R²: {r2_nn:.3f}")

# ── 5.  Add to your results list ─────────────────────────────────────────
results_tornado.append({
    "Model": "Neural Network (PyTorch, Tornado)",
    "RMSE":  rmse_nn,
    "R² Score": r2_nn
})
# Out:
# PyTorch NN  RMSE: 10.26   R²: -0.056

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(preds_z,  label='Predicted Value')
plt.ylim(-20, 30)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# at the end of training, after your loop:
#torch.save(model.state_dict(), "Models/mlp_regressor_state_dict_flash_flood.pth")

# %% [markdown]
# # XGA Boost Regressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
X_train_scaled_flood
# Out:
#      injuries_direct  deaths_direct  event_latitude  event_longitude  \
# 115        -0.304428      -0.088736        0.967709         0.441951
# 2          -0.304428      -0.088736        0.929216        -1.242785
# 123        -0.487370      -0.088736       -1.257915         0.769587
# 45          2.073824      -0.088736       -0.960741         1.437592
# 42         -0.121485      -0.088736       -0.021387         0.974554
# ..               ...            ...             ...              ...
# 71         -0.487370      -0.088736       -0.493933        -0.387543
# 106        -0.487370      -0.088736        1.656670        -0.937226
# 14          0.793227      -0.088736        0.062792        -0.656795
# 92         -0.487370      -0.088736        1.019880        -1.231987
# 102        -0.487370      -0.088736       -1.117618         0.284189
#
#      event_range  event_duration  source_AMATEUR RADIO  source_Amateur Radio  \
# 115     0.770812       -0.696718             -0.125988             -0.179605
# 2       0.161750        0.258537             -0.125988             -0.179605
# 123     0.161750        1.486723             -0.125988             -0.179605
# 45     -0.853352       -0.423788             -0.125988             -0.179605
# 42     -0.853352       -0.492021             -0.125988             -0.179605
# ..           ...             ...                   ...                   ...
# 71     -0.713268       -0.560253             -0.125988             -0.179605
# 106     0.567791       -0.696718             -0.125988             -0.179605
# 14      0.094753       -0.355555             -0.125988             -0.179605
# 92     -0.532580       -0.696718             -0.125988             -0.179605
# 102    -0.548822       -0.696718             -0.125988             -0.179605
#
#      source_Broadcast Media  source_COOP Observer  ...  source_NEWSPAPER  \
# 115               -0.240523             -0.125988  ...         -0.179605
# 2                 -0.240523             -0.125988  ...         -0.179605
# 123               -0.240523             -0.125988  ...         -0.179605
# 45                -0.240523             -0.125988  ...         -0.179605
# 42                -0.240523             -0.125988  ...         -0.179605
# ..                      ...                   ...  ...               ...
# 71                -0.240523             -0.125988  ...         -0.179605
# 106               -0.240523             -0.125988  ...         -0.179605
# 14                 4.157609             -0.125988  ...         -0.179605
# 92                -0.240523              7.937254  ...         -0.179605
# 102               -0.240523             -0.125988  ...         -0.179605
#
#      source_NWS Employee  source_NWS STORM SURVEY  source_NWS Storm Survey  \
# 115            -0.154919                -0.201619                -0.221766
# 2              -0.154919                -0.201619                -0.221766
# 123            -0.154919                -0.201619                -0.221766
# 45             -0.154919                -0.201619                -0.221766
# 42             -0.154919                -0.201619                -0.221766
# ..                   ...                      ...                      ...
# 71             -0.154919                -0.201619                -0.221766
# 106            -0.154919                -0.201619                -0.221766
# 14             -0.154919                -0.201619                -0.221766
# 92             -0.154919                -0.201619                -0.221766
# 102            -0.154919                -0.201619                -0.221766
#
#      source_Newspaper  source_OFFICIAL NWS OBS.  source_Public  \
# 115         -0.179605                 -0.125988      -0.468025
# 2           -0.179605                 -0.125988       2.136637
# 123         -0.179605                 -0.125988      -0.468025
# 45          -0.179605                 -0.125988      -0.468025
# 42          -0.179605                 -0.125988      -0.468025
# ..                ...                       ...            ...
# 71          -0.179605                 -0.125988       2.136637
# 106         -0.179605                 -0.125988       2.136637
# 14          -0.179605                 -0.125988      -0.468025
# 92          -0.179605                 -0.125988      -0.468025
# 102         -0.179605                 -0.125988       2.136637
#
#      source_Social Media  source_TRAINED SPOTTER  source_Trained Spotter
# 115                  0.0               -0.221766               -0.404520
# 2                    0.0               -0.221766               -0.404520
# 123                  0.0               -0.221766               -0.404520
# 45                   0.0               -0.221766                2.472066
# 42                   0.0               -0.221766               -0.404520
# ..                   ...                     ...                     ...
# 71                   0.0               -0.221766               -0.404520
# 106                  0.0               -0.221766               -0.404520
# 14                   0.0               -0.221766               -0.404520
# 92                   0.0               -0.221766               -0.404520
# 102                  0.0               -0.221766               -0.404520
#
# [128 rows x 28 columns]

# %%
xgb_model = XGBRegressor(
    n_estimators=800,        # total boosted trees
    learning_rate=0.03,     # shrinkage (η)
    max_depth=6,            # tree depth
    subsample=0.8,          # row sampling
    colsample_bytree=0.8,   # feature sampling
    objective="reg:squarederror",
    reg_lambda=1.0,         # L2 regularisation
    random_state=42,
    n_jobs=-1,              # use all CPU cores
)

# Optionally try a log‑target wrapper (similar to TransformedTargetRegressor)
# if you still have huge dynamic‑range issues.

xgb_model.fit(X_train_scaled_flood, y_train_flood)

y_pred_xgb = xgb_model.predict(X_test_scaled_flood)

rmse_xgb = np.sqrt(mean_squared_error(y_test_flood, y_pred_xgb))
r2_xgb   = r2_score(y_test_flood, y_pred_xgb)

print(f"XGBoost  RMSE: {rmse_xgb:,.2f}   R²: {r2_xgb:.3f}")


results_tornado.append({
    "Model": "XGBoost Regressor (Tornado)",
    "RMSE":  rmse_xgb,
    "R² Score": r2_xgb
})
# Out:
# XGBoost  RMSE: 6.37   R²: 0.031

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred_xgb,  label='Predicted Value')
plt.ylim(-20, 30)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#joblib.dump(xgb_model, "Models/xgb_tornado_flash_flood.joblib")

# %% [markdown]
# # Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from scipy.stats import loguniform
from sklearn.model_selection import RandomizedSearchCV

# %%
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("svr", SVR(kernel="rbf"))
])

svr_ttr = TransformedTargetRegressor(
    regressor=pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

svr_ttr.fit(X_train_scaled_flood, y_train_flood)
# Out:
# TransformedTargetRegressor(func=<ufunc 'log1p'>, inverse_func=<ufunc 'expm1'>,
#                            regressor=Pipeline(steps=[('scaler',
#                                                       StandardScaler()),
#                                                      ('svr', SVR())]))

# %%
y_pred = svr_ttr.predict(X_test_scaled_flood)     # already inverse‑transformed
rmse_svr   = np.sqrt(mean_squared_error(y_test_flood, y_pred))
r2_svr     = r2_score(y_test_flood, y_pred)

# %%
print(f"SVR  RMSE: {rmse_svr:,.2f}   R²: {r2_svr:.3f}")
# Out:
# SVR  RMSE: 8.52   R²: -0.736

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred,  label='Predicted Value')
plt.ylim(-20, 40)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
joblib.dump(svr_ttr, "Models/svr_pipeline_flash_floods.joblib")
# Out:
# ['Models/svr_pipeline_flash_floods.joblib']

# %% [markdown]
# # Adaboost Regressor

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
ada_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("ada", AdaBoostRegressor(
        n_estimators=100,
        learning_rate=0.1,
        random_state=42
    )),
])

ada_ttr = TransformedTargetRegressor(
    regressor=ada_pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

ada_ttr.fit(X_train_scaled_flood, y_train_flood)
y_pred_ada = ada_ttr.predict(X_test_scaled_flood)   # inverse‑transformed
rmse_ada = np.sqrt(mean_squared_error(y_test_flood, y_pred_ada))
r2_ada   = r2_score(y_test_flood, y_pred_ada)

print(f"AdaBoost   RMSE: {rmse_ada:.2f}   R²: {r2_ada:.3f}")
# Out:
# AdaBoost   RMSE: 7.48   R²: -0.336

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred_ada,  label='Predicted Value')
plt.ylim(-20, 40)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#joblib.dump(ada_ttr, "Models/ada_pipeline_flash_floods.joblib")

# %% [markdown]
# # KNN Regressor

# %%
knn_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsRegressor(
        n_neighbors=5,
        weights="uniform",
        n_jobs=-1
    )),
])

knn_ttr = TransformedTargetRegressor(
    regressor=knn_pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

knn_ttr.fit(X_train_scaled_flood, y_train_flood)
y_pred_knn = knn_ttr.predict(X_test_scaled_flood)  # inverse‑transformed
rmse_knn = np.sqrt(mean_squared_error(y_test_flood, y_pred_knn))
r2_knn   = r2_score(y_test_flood, y_pred_knn)

print(f"KNN        RMSE: {rmse_knn:.2f}   R²: {r2_knn:.3f}")
# Out:
# KNN        RMSE: 8.82   R²: -0.861

# %%
plt.figure(figsize=(8, 5))
plt.plot(y_test_flood.values,  label='True Value')
plt.plot(y_pred_knn,  label='Predicted Value')
plt.ylim(-20, 40)  
#plt.plot(smooth, linewidth=2, label='Smoothed (5‑epoch MA)')
plt.xlabel('Sample Index')
plt.ylabel('Damage Cost')
#plt.title('Validation loss (raw & smoothed)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
